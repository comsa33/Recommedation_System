# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from io import BytesIO
from PIL import Image
from IPython.display import display
import textdistance
import time
from glob import glob

from preprocess import Preprocess

# %%
class SEARCH_RECOMMEND:
    
    def __init__(self, df, qval=None, style_ths=0.1):

        self.style_ths_str = str(style_ths)[-1]
        self.compare_y = False
        self.df = df
        self.qval = qval  # Q-Value : 거리 유사도 알고리즘에서 q-gram 으로 문장을 어떻게 나눌지 결정하는 파라미터 (None:단어기반, 1:철자기반, 2~more:q-gram)
        self.df_ = self.preprocess_df(self.df)  # new_tag feature를 새롭게 추가 전처리
        self.user_item_set = set()  # 사용자가 아이템을 선택(검색/추천)시 => 사용자가 선택한 아이템 목록
        self.cold_start = True   # Cold Start : 최적화된 추천 알고리즘 선택을 위해 사용자의 아이템 목록이 비어있는지 확인하는 변수
        
    def preprocess_df(self, df):
        # make new-tag
        # top3_style, tags, name, projectId 를 하나의 string으로 만들기
        df['new_tag'] = list(
                            zip(
                                df[f'top_style_{self.style_ths_str}'].tolist(), 
                                df['tags'].tolist(),
                                df['name'].tolist(),
                                df['projectId'].tolist()
                                )
                            )
        df['new_tag'] = df['new_tag'].apply(self.reduce_newtag)
        df['new_tag'] = df['new_tag'].apply(lambda x: ' '.join(x).lower())
        return df
    
    def reduce_newtag(self, x):
        newtag = []
        for tag in x:
            if type(tag) == str:
                newtag.append(tag)
            else:
                newtag.extend(tag)
        return newtag
    
    # 사용자 셋에 아이템 추가
    def add_item_in_user_item_set(self, prod):
        print(f'사용자 님의 아이템 목록에 [{prod}]를 추가합니다.')
        id_ = self.df_[self.df_['name'] == prod]['product_id'].values[0]
        self.user_item_set.add(id_)
        self.cold_start = False
        print(f'사용자 님이 현재 선택한 아이템 목록 : {self.user_item_set}')
        return id_
    
    # 사용자 셋에서 아이템 제거
    def remove_item_from_user_item_set(self, prod):
        print(f'사용자 님의 아이템 목록에서 [{prod}]를 제거합니다.')
        id_ = self.df_[self.df_['name'] == prod]['product_id'].values[0]
        self.user_item_set.remove(id_)
        print(f'사용자 님의 현재 남아있는 선택된 아이템 목록 : {self.user_item_set}')
        # 사용자 목록이 비게 되면 콜드스타트
        if len(self.user_item_set) > 1:
            self.cold_start = True
    
    # 사용자가 선택한 아이템과 데이터 내 모든 아이템들과의 유사도 계산
    def get_similarity_score(self, search_prod_tag, algo='sorensen'):
        """
        search_prod_tag : string, 사용자가 선택한 아이템 이름으로부터 매칭된 self.df_['new_tag'].values
        """
        # calculate similarity
        sim_score = []
        new_tag = self.df_['new_tag'].tolist()
        start_time = time.time()
        for i, tag in enumerate(new_tag):
            if algo == 'sorensen':
                sim_score.append(textdistance.Sorensen(qval=self.qval, as_set=True).normalized_similarity(search_prod_tag, tag))
            elif algo == 'ncd':
                sim_score.append(textdistance.EntropyNCD(qval=self.qval).normalized_similarity(search_prod_tag, tag))
        print(f'검색 태그 : {search_prod_tag}')
        print(f'검색 시간 : {round(time.time()-start_time, 4)}초')
        print()
        return sim_score
    
    # 사용자 선택한 아이템/아이템 목록으로부터 유사도를 통해 아이템 추천
    def search_product(self, prod, topn=10, algo='sorensen'):
        """
        prod : string, 아이템 이름
        topn : int, 유사도 상위 n개의 아이템 추천
        algo : 'sorensen' - 토큰 기반 거리 유사도 알고리즘, 'ncd' - 문장 압축을 통한 유사도 알고리즘
        """
        # 아이템을 사용자 아이템 목록에 추가
        # declare id, category of searching product
        id_ = self.add_item_in_user_item_set(prod)
        prod_cat = self.df_[self.df_['product_id'] == id_]['name_x'].values[0]
        if prod_cat == np.nan:
            prod_cat = self.df_[self.df_['product_id'] == id_]['name_y'].values[0]
            self.compare_y = True
        
        print(f"검색 아이템이 해당한 프로젝트 ID : {self.df_[self.df_['name'] == prod]['projectId'].values[0]}")
        
        if self.cold_start:
            # retrieve the product tag from the input product id
            # 동일 아이템이 여러 전문가에 사용될 경우 => awesome_score 가 더 높은 점수를 받은 아이템의 new_tag를 가져옴
            search_prod_tag = self.df_[self.df_['product_id'] == id_].sort_values(by='awesome_score', ascending=False)['new_tag'].values[0]
        else:
            search_prod_tag = ''
            for existing_item_id in self.user_item_set:
                temp_id = self.df_[self.df_['product_id'] == existing_item_id].sort_values(by='awesome_score', ascending=False)['new_tag'].values[0]
                search_prod_tag += temp_id+' '
            search_prod_tag = search_prod_tag[:-1]
            
        # 해당 아이템-다른 아이템 간 유사도 계산
        sim_score = self.get_similarity_score(search_prod_tag, algo=algo)
        
        # save result
        sim_score = np.asarray(sim_score)  # [사용자가 선택한 아이템-다른 모든 아이템] 간 유사도 점수
        sim_score_idx = np.arange(len(sim_score)) # 유사도 점수에 대한 인덱스
        
        result_df = self.df_.iloc[sim_score_idx][['product_id', 'name', 
                                                  'new_tag', 'projectId', 
                                                  'images', 'name_x', 'name_y']]
        result_df['similarity'] = sim_score
        
        # filtering
        result_df = result_df[result_df['product_id']!=id_]  # 사용자가 선택한 아이템과 동일한 아이템 제거
        result_df = result_df.drop_duplicates(['product_id'])  # 중복된 아이템 제거
        print(prod_cat)
        # 사용자가 선택한 아이템과 동일한 카테고리의 추천된 아이템들 제거
        if self.compare_y:
            result_df = result_df[result_df['name_y'] != prod_cat]
        else:
            result_df = result_df[result_df['name_x'] != prod_cat] 
        result_df = result_df.sort_values(by='similarity', ascending=False).reset_index()[:topn] # 유사도가 가장 높은 순서대로 정렬 => top-n개 까지 추천 결과 저장
        
        # show result image
        print(f'사용자가 선택한 아이템 : {prod}')
        try:
            prod_res = requests.get(self.df_[self.df_['name'] == prod]['images'].values[0][0])
            display(Image.open(BytesIO(prod_res.content)))
        except:
            print('이미지 없음\n')
            print()

        print("="*80)
        print(f"추천 아이템 Top{topn}")
        print("="*80)
        
        i = 1
        for name, img_url in result_df[['name', 'images']].values:
            print(f"추천 {i}순위 : {name}")
            try:
                res = requests.get(img_url[0])
                img = Image.open(BytesIO(res.content))
                display(img)
            except:
                print('이미지 없음\n')
            print("-"*60)
            i += 1

        self.result = result_df

# %%
# base_path = '2022-03-07/'
# file_paths = [
#     base_path + 'bestshots.json', 
#     base_path + 'items.json', 
#     base_path +'categories.json', 
#     base_path +'products.json'
# ]

# %%
base_bath = '22-03-07/'

# abs path -> 22-03-07/ *.json
best = glob(base_bath+'best*.json')
item = glob(base_bath+'item*.json')
products = glob(base_bath+'products*.json')
#category1 == category2 = True
category = glob(base_bath+'category*.json')

# %%
# 데이터전처리 클래스로부터 객체 선언하기

style_ths = 0.1
style_ths_str = str(style_ths)[-1]
st = time.time()
DATA = Preprocess(best, item, products, category, style_ths=style_ths)
print(f"{time.time()-st}초")
# Out:
# C:\Users\jumpx\Downloads\new\new\preprocess.py:84: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   items_stack = pd.DataFrame(templates['items'].apply(lambda x: pd.Series(x)).stack()).reset_index(1, drop=True)
# 3.522575616836548초

# %%
best_item_df, products_df_4, products_df_b = DATA.best_item, DATA.products_4, DATA.products_b
best_item_df.shape, products_df_4.shape, products_df_b.shape
# Out:
# ((4556, 38), (4774, 15), (50143, 16))

# %%
products_df_b[products_df_b['name_x'] == 'Lighting']
# Out:
#           enterprise_id                projectId  \
# 10910  B57D4F97C0E44A11  X1NUTfX857BBAB86D92406B
# 10911  B57D4F97C0E44A11  X5EvZH8185ABBECDF7C4EB3
# 15712  B57D4F97C0E44A11  X8LpuJw14563EF31C234143
# 15713  B57D4F97C0E44A11  X8LpuJw14563EF31C234143
# 15714  B57D4F97C0E44A11  X8LpuJw14563EF31C234143
# 15715  B57D4F97C0E44A11  X8LpuJw14563EF31C234143
# 15716  B57D4F97C0E44A11  X8LpuJw14563EF31C234143
# 15717  B57D4F97C0E44A11  X8LpuJw14563EF31C234143
# 22878  B57D4F97C0E44A11  X9ZLXcq0BD61A990DA24DA3
# 23247  B57D4F97C0E44A11  X5MQQCl0247E2804E4D4FD2
# 23248  B57D4F97C0E44A11  X5MQQCl0247E2804E4D4FD2
# 23249  B57D4F97C0E44A11  X5MQQCl0247E2804E4D4FD2
# 23250  B57D4F97C0E44A11  X5MQQCl0247E2804E4D4FD2
# 23251  B57D4F97C0E44A11  X5MQQCl0247E2804E4D4FD2
# 23252  B57D4F97C0E44A11  X0o0RF7E5C4A9B3BA714C83
# 23325  B57D4F97C0E44A11  X5MQQCl0247E2804E4D4FD2
# 23326  B57D4F97C0E44A11  X5MQQCl0247E2804E4D4FD2
# 23327  B57D4F97C0E44A11  X5MQQCl0247E2804E4D4FD2
# 23328  B57D4F97C0E44A11  X5MQQCl0247E2804E4D4FD2
# 23329  B57D4F97C0E44A11  X5MQQCl0247E2804E4D4FD2
# 23330  B57D4F97C0E44A11  X4uf9r180552EA7FCBC495A
# 23331  B57D4F97C0E44A11  X5H3nza400C56EDB1C3469F
# 23332  B57D4F97C0E44A11  X0o0RF7E5C4A9B3BA714C83
# 23376  B57D4F97C0E44A11  X6_iNeTF969A2526A154087
# 23377  B57D4F97C0E44A11  X5tKCH5387E6684E7BB4810
# 39125  B57D4F97C0E44A11  X4jq4Pe83CAD7F6CAF749F1
# 45230  B57D4F97C0E44A11  X5XAHC06733FD471DB942BE
# 45231  B57D4F97C0E44A11  X4zAZjKFA7C135476D04B33
# 47219  B57D4F97C0E44A11  X6_iNeTF969A2526A154087
# 47914  B57D4F97C0E44A11  X4uf9r180552EA7FCBC495A
# 47915  B57D4F97C0E44A11  X5HW0Qo7968CA82B4FD4D45
# 48922  B57D4F97C0E44A11  X5a8ODs03BCECB6EF8941A7
# 49414  B57D4F97C0E44A11  X5J-O826593ACA0792B4618
# 49535  B57D4F97C0E44A11  X5HW0Qo7968CA82B4FD4D45
# 49538  B57D4F97C0E44A11  X5HW0Qo7968CA82B4FD4D45
# 49541  B57D4F97C0E44A11  X5HW0Qo7968CA82B4FD4D45
# 49542  B57D4F97C0E44A11  X5HW0Qo7968CA82B4FD4D45
# 49939  B57D4F97C0E44A11  X4jq4Pe83CAD7F6CAF749F1
# 49942  B57D4F97C0E44A11  X4jq4Pe83CAD7F6CAF749F1
#
#                          top_style_1 top_style  awesome_score  \
# 10910              [NATURAL, MODERN]   NATURAL       0.942249
# 10911                       [MODERN]    MODERN       0.866041
# 15712                      [NATURAL]   NATURAL       0.978909
# 15713                      [NATURAL]   NATURAL       0.978909
# 15714                      [NATURAL]   NATURAL       0.978909
# 15715                      [NATURAL]   NATURAL       0.978909
# 15716     [VINTAGE, NATURAL, MODERN]   VINTAGE       0.976012
# 15717                      [NATURAL]   NATURAL       0.916045
# 22878        [NATURAL, SCANDINAVIAN]   NATURAL       0.976050
# 23247              [NATURAL, MODERN]   NATURAL       0.971177
# 23248              [NATURAL, MODERN]   NATURAL       0.989268
# 23249                       [MODERN]    MODERN       0.971501
# 23250                       [MODERN]    MODERN       0.974794
# 23251                       [MODERN]    MODERN       0.942095
# 23252                       [MODERN]    MODERN       0.817221
# 23325              [NATURAL, MODERN]   NATURAL       0.971177
# 23326              [NATURAL, MODERN]   NATURAL       0.989268
# 23327                       [MODERN]    MODERN       0.971501
# 23328                       [MODERN]    MODERN       0.974794
# 23329                       [MODERN]    MODERN       0.942095
# 23330                       [MODERN]    MODERN       0.960531
# 23331              [NATURAL, MODERN]   NATURAL       0.884047
# 23332                       [MODERN]    MODERN       0.817221
# 23376              [MODERN, NATURAL]    MODERN       0.893662
# 23377              [NATURAL, MODERN]   NATURAL       0.987702
# 39125              [MODERN, NATURAL]    MODERN       0.942830
# 45230  [NATURAL, MID_CENTURY_MODERN]   NATURAL       0.915732
# 45231                      [NATURAL]   NATURAL       0.930636
# 47219              [MODERN, NATURAL]    MODERN       0.893662
# 47914                       [MODERN]    MODERN       0.960531
# 47915                      [NATURAL]   NATURAL       0.946334
# 48922              [MODERN, NATURAL]    MODERN       0.952172
# 49414              [MODERN, NATURAL]    MODERN       0.953887
# 49535                      [NATURAL]   NATURAL       0.946334
# 49538                      [NATURAL]   NATURAL       0.946334
# 49541                      [NATURAL]   NATURAL       0.946334
# 49542                      [NATURAL]   NATURAL       0.946334
# 49939              [MODERN, NATURAL]    MODERN       0.942830
# 49942              [MODERN, NATURAL]    MODERN       0.942830
#
#                     product_id  use_count                      _id  \
# 10910         FB9EA7E54E064C80         15         FB9EA7E54E064C80
# 10911         FB9EA7E54E064C80         15         FB9EA7E54E064C80
# 15712  XhYAPoY15189AE67C5A4093          7  XhYAPoY15189AE67C5A4093
# 15713  XhYAPoY15189AE67C5A4093          7  XhYAPoY15189AE67C5A4093
# 15714  XhYAPoY15189AE67C5A4093          7  XhYAPoY15189AE67C5A4093
# 15715  XhYAPoY15189AE67C5A4093          7  XhYAPoY15189AE67C5A4093
# 15716  XhYAPoY15189AE67C5A4093          7  XhYAPoY15189AE67C5A4093
# 15717  XhYAPoY15189AE67C5A4093          7  XhYAPoY15189AE67C5A4093
# 22878  XiRLX9G45E624F42ADB4EE4          1  XiRLX9G45E624F42ADB4EE4
# 23247  XmraD1yAD1CB4765AE243CF          7  XmraD1yAD1CB4765AE243CF
# 23248  XmraD1yAD1CB4765AE243CF          7  XmraD1yAD1CB4765AE243CF
# 23249  XmraD1yAD1CB4765AE243CF          7  XmraD1yAD1CB4765AE243CF
# 23250  XmraD1yAD1CB4765AE243CF          7  XmraD1yAD1CB4765AE243CF
# 23251  XmraD1yAD1CB4765AE243CF          7  XmraD1yAD1CB4765AE243CF
# 23252  XmraD1yAD1CB4765AE243CF          7  XmraD1yAD1CB4765AE243CF
# 23325         32CB7FA2721A48A1         34         32CB7FA2721A48A1
# 23326         32CB7FA2721A48A1         34         32CB7FA2721A48A1
# 23327         32CB7FA2721A48A1         34         32CB7FA2721A48A1
# 23328         32CB7FA2721A48A1         34         32CB7FA2721A48A1
# 23329         32CB7FA2721A48A1         34         32CB7FA2721A48A1
# 23330         32CB7FA2721A48A1         34         32CB7FA2721A48A1
# 23331         32CB7FA2721A48A1         34         32CB7FA2721A48A1
# 23332         32CB7FA2721A48A1         34         32CB7FA2721A48A1
# 23376  XmraD1x8F6516B7D0614DC2          5  XmraD1x8F6516B7D0614DC2
# 23377  XmraD1x8F6516B7D0614DC2          5  XmraD1x8F6516B7D0614DC2
# 39125  XhNzkbM05E41704E1F94151          2  XhNzkbM05E41704E1F94151
# 45230         4AE100C4B3434250          4         4AE100C4B3434250
# 45231         4AE100C4B3434250          4         4AE100C4B3434250
# 47219  XmraD1o3AB8D16D7E3D4E7A          1  XmraD1o3AB8D16D7E3D4E7A
# 47914  XmHnfZD2F11231BDF514694          2  XmHnfZD2F11231BDF514694
# 47915  XmHnfZD2F11231BDF514694          2  XmHnfZD2F11231BDF514694
# 48922  XZudEjr0388DCF81E084CBC          2  XZudEjr0388DCF81E084CBC
# 49414  XiMPF_Q22A42A1A76E44F13          1  XiMPF_Q22A42A1A76E44F13
# 49535  Xl-0njH3D2478F0B1964D6E          1  Xl-0njH3D2478F0B1964D6E
# 49538  Xo23eCoD872DCD451B44AF7          1  Xo23eCoD872DCD451B44AF7
# 49541  XiwX1Zl61576D67D2A043CF          2  XiwX1Zl61576D67D2A043CF
# 49542  XivZXoBE3E39EAFF06E486E          1  XivZXoBE3E39EAFF06E486E
# 49939  XXPjWDQ014F1330948B479B          1  XXPjWDQ014F1330948B479B
# 49942  Xhc_iSk06B654C143544AA4          1  Xhc_iSk06B654C143544AA4
#
#                                   name  \
# 10910    Archisketch Ceiling Square_on
# 10911    Archisketch Ceiling Square_on
# 15712         Discoco 53 White_1500_on
# 15713         Discoco 53 White_1500_on
# 15714         Discoco 53 White_1500_on
# 15715         Discoco 53 White_1500_on
# 15716         Discoco 53 White_1500_on
# 15717         Discoco 53 White_1500_on
# 22878                       아키라 55A_on
# 23247             미니 램프 드 마르세유(화이트)_on
# 23248             미니 램프 드 마르세유(화이트)_on
# 23249             미니 램프 드 마르세유(화이트)_on
# 23250             미니 램프 드 마르세유(화이트)_on
# 23251             미니 램프 드 마르세유(화이트)_on
# 23252             미니 램프 드 마르세유(화이트)_on
# 23325      Archisketch Circle Light_on
# 23326      Archisketch Circle Light_on
# 23327      Archisketch Circle Light_on
# 23328      Archisketch Circle Light_on
# 23329      Archisketch Circle Light_on
# 23330      Archisketch Circle Light_on
# 23331      Archisketch Circle Light_on
# 23332      Archisketch Circle Light_on
# 23376            판텔라 미니 테이블 램프(화이트)_on
# 23377            판텔라 미니 테이블 램프(화이트)_on
# 39125                  아스테리아 플로어 램프_on
# 45230  Archisketch Ceiling IES Lamp_on
# 45231  Archisketch Ceiling IES Lamp_on
# 47219                   PH5  펜던트 램프_on
# 47914         나이트 아울 테이블 램프(화이트/우드)_on
# 47915         나이트 아울 테이블 램프(화이트/우드)_on
# 48922                아리아 펜던트 (150w)_on
# 49414                 UPPLYST 우플뤼스트_on
# 49535        루미오 북램프 클래식_180도(메이플)_off
# 49538            네씨노 테이블 램프 (White)_on
# 49541            베르너 천장실링팬 조명 (목재)_off
# 49542                라미스 1등 인테리어조명_off
# 49939    에밀리 램프 위드 셰이드_베드사이드(아이보리)_off
# 49942    Atollo Metal Large (white)_on
#
#                                                     tags  \
# 10910                                                 []
# 10911                                                 []
# 15712       [마르셋, Marset, 조명, 팬던트가구, 팬던트램프, 조명인테리어, 럭셔리]
# 15713       [마르셋, Marset, 조명, 팬던트가구, 팬던트램프, 조명인테리어, 럭셔리]
# 15714       [마르셋, Marset, 조명, 팬던트가구, 팬던트램프, 조명인테리어, 럭셔리]
# 15715       [마르셋, Marset, 조명, 팬던트가구, 팬던트램프, 조명인테리어, 럭셔리]
# 15716       [마르셋, Marset, 조명, 팬던트가구, 팬던트램프, 조명인테리어, 럭셔리]
# 15717       [마르셋, Marset, 조명, 팬던트가구, 팬던트램프, 조명인테리어, 럭셔리]
# 22878        [vitra, 비트라, 아카리, 조명, 팬던트조명, 천장조명, 팬던트, 천장]
# 23247                                            [TRDST]
# 23248                                            [TRDST]
# 23249                                            [TRDST]
# 23250                                            [TRDST]
# 23251                                            [TRDST]
# 23252                                            [TRDST]
# 23325                                                 []
# 23326                                                 []
# 23327                                                 []
# 23328                                                 []
# 23329                                                 []
# 23330                                                 []
# 23331                                                 []
# 23332                                                 []
# 23376     [루이스폴센, louispoulsen, 도명, 테이블램프, 탁상스탠드, 스탠드조명]
# 23377     [루이스폴센, louispoulsen, 도명, 테이블램프, 탁상스탠드, 스탠드조명]
# 39125                     [우메이, umage, 플로어램프, 조명, 스탠드조명]
# 45230                                                 []
# 45231                                                 []
# 47219    [루이스폴센, louispoulsen, 조명, 팬던트조명, 천장조명, 팬던트, 천장]
# 47914                [프리츠한센, fritzhansen, 램프, 테이블램프, 조명]
# 47915                [프리츠한센, fritzhansen, 램프, 테이블램프, 조명]
# 48922                       [까사인루체, casainluce, 조명, 천장등]
# 49414                               [이케아, IKEA, 스탠드, 조명]
# 49535            [루미오, Lumio, 북램프, 램프, 조명, 조명인테리어, 조명가구]
# 49538                     [아르떼미데, artemide, 램프, 책상등, 조명]
# 49541  [vittz, 비츠, 베르너, 천장실링팬, 실링팬, 천장, 우드, 나무, 네추럴, ...
# 49542                                                 []
# 49939  [포터리반, Potteryban, 램프, 테이블램프, 침실조명, 스탠드, 침실스탠드...
# 49942   [Atollo, 아톨로, 단스탠드, 조명, 테이블조명, 워뿔, 기하학, 반구, 화이트]
#
#                                               dimensions  \
# 10910  {'width': 450, 'height': 20, 'depth': 200, 'un...
# 10911  {'width': 450, 'height': 20, 'depth': 200, 'un...
# 15712  {'width': 512, 'height': 1832, 'depth': 478, '...
# 15713  {'width': 512, 'height': 1832, 'depth': 478, '...
# 15714  {'width': 512, 'height': 1832, 'depth': 478, '...
# 15715  {'width': 512, 'height': 1832, 'depth': 478, '...
# 15716  {'width': 512, 'height': 1832, 'depth': 478, '...
# 15717  {'width': 512, 'height': 1832, 'depth': 478, '...
# 22878  {'width': 550, 'height': 1500, 'depth': 550, '...
# 23247  {'width': 300, 'height': 440, 'depth': 1020, '...
# 23248  {'width': 300, 'height': 440, 'depth': 1020, '...
# 23249  {'width': 300, 'height': 440, 'depth': 1020, '...
# 23250  {'width': 300, 'height': 440, 'depth': 1020, '...
# 23251  {'width': 300, 'height': 440, 'depth': 1020, '...
# 23252  {'width': 300, 'height': 440, 'depth': 1020, '...
# 23325  {'width': 140, 'height': 18, 'depth': 140, 'un...
# 23326  {'width': 140, 'height': 18, 'depth': 140, 'un...
# 23327  {'width': 140, 'height': 18, 'depth': 140, 'un...
# 23328  {'width': 140, 'height': 18, 'depth': 140, 'un...
# 23329  {'width': 140, 'height': 18, 'depth': 140, 'un...
# 23330  {'width': 140, 'height': 18, 'depth': 140, 'un...
# 23331  {'width': 140, 'height': 18, 'depth': 140, 'un...
# 23332  {'width': 140, 'height': 18, 'depth': 140, 'un...
# 23376  {'width': 250, 'height': 335, 'depth': 250, 'u...
# 23377  {'width': 250, 'height': 335, 'depth': 250, 'u...
# 39125  {'width': 430, 'height': 1500, 'depth': 428, '...
# 45230  {'width': 251, 'height': 40, 'depth': 247, 'un...
# 45231  {'width': 251, 'height': 40, 'depth': 247, 'un...
# 47219  {'width': 500, 'height': 1640, 'depth': 500, '...
# 47914  {'width': 230, 'height': 240, 'depth': 150, 'u...
# 47915  {'width': 230, 'height': 240, 'depth': 150, 'u...
# 48922  {'width': 150, 'height': 1156, 'depth': 150, '...
# 49414  {'width': 320, 'height': 200, 'depth': 80, 'un...
# 49535  {'width': 340, 'height': 215, 'depth': 170, 'u...
# 49538  {'width': 320, 'height': 223, 'depth': 320, 'u...
# 49541  {'width': 1155, 'height': 169, 'depth': 1012, ...
# 49542  {'width': 345, 'height': 1999, 'depth': 216, '...
# 49939  {'width': 318, 'height': 572, 'depth': 318, 'u...
# 49942  {'width': 499, 'height': 694, 'depth': 502, 'u...
#
#                                                   images    name_x  \
# 10910                                                 []  Lighting
# 10911                                                 []  Lighting
# 15712  [https://resources.archisketch.com/product/XhY...  Lighting
# 15713  [https://resources.archisketch.com/product/XhY...  Lighting
# 15714  [https://resources.archisketch.com/product/XhY...  Lighting
# 15715  [https://resources.archisketch.com/product/XhY...  Lighting
# 15716  [https://resources.archisketch.com/product/XhY...  Lighting
# 15717  [https://resources.archisketch.com/product/XhY...  Lighting
# 22878  [https://resources.archisketch.com/product/XiR...  Lighting
# 23247  [https://resources.archisketch.com/product/Xmr...  Lighting
# 23248  [https://resources.archisketch.com/product/Xmr...  Lighting
# 23249  [https://resources.archisketch.com/product/Xmr...  Lighting
# 23250  [https://resources.archisketch.com/product/Xmr...  Lighting
# 23251  [https://resources.archisketch.com/product/Xmr...  Lighting
# 23252  [https://resources.archisketch.com/product/Xmr...  Lighting
# 23325  [https://resources.archisketch.com/product/32C...  Lighting
# 23326  [https://resources.archisketch.com/product/32C...  Lighting
# 23327  [https://resources.archisketch.com/product/32C...  Lighting
# 23328  [https://resources.archisketch.com/product/32C...  Lighting
# 23329  [https://resources.archisketch.com/product/32C...  Lighting
# 23330  [https://resources.archisketch.com/product/32C...  Lighting
# 23331  [https://resources.archisketch.com/product/32C...  Lighting
# 23332  [https://resources.archisketch.com/product/32C...  Lighting
# 23376  [https://resources.archisketch.com/product/Xmr...  Lighting
# 23377  [https://resources.archisketch.com/product/Xmr...  Lighting
# 39125  [https://resources.archisketch.com/product/XhN...  Lighting
# 45230  [https://resources.archisketch.com/product/4AE...  Lighting
# 45231  [https://resources.archisketch.com/product/4AE...  Lighting
# 47219  [https://resources.archisketch.com/product/Xmr...  Lighting
# 47914  [https://resources.archisketch.com/product/XmH...  Lighting
# 47915  [https://resources.archisketch.com/product/XmH...  Lighting
# 48922  [https://resources.archisketch.com/product/XZu...  Lighting
# 49414  [https://resources.archisketch.com/product/XiM...  Lighting
# 49535  [https://resources.archisketch.com/product/Xl-...  Lighting
# 49538  [https://resources.archisketch.com/product/Xo2...  Lighting
# 49541  [https://resources.archisketch.com/product/Xiw...  Lighting
# 49542  [https://resources.archisketch.com/product/Xiv...  Lighting
# 49939  [https://resources.archisketch.com/product/XXP...  Lighting
# 49942  [https://resources.archisketch.com/product/Xhc...  Lighting
#
#                       name_y name_z
# 10910  LED Ceiling Lightings    NaN
# 10911  LED Ceiling Lightings    NaN
# 15712         Ceiling Lights    NaN
# 15713         Ceiling Lights    NaN
# 15714         Ceiling Lights    NaN
# 15715         Ceiling Lights    NaN
# 15716         Ceiling Lights    NaN
# 15717         Ceiling Lights    NaN
# 22878         Ceiling Lights    NaN
# 23247            Wall Lights    NaN
# 23248            Wall Lights    NaN
# 23249            Wall Lights    NaN
# 23250            Wall Lights    NaN
# 23251            Wall Lights    NaN
# 23252            Wall Lights    NaN
# 23325  LED Ceiling Lightings    NaN
# 23326  LED Ceiling Lightings    NaN
# 23327  LED Ceiling Lightings    NaN
# 23328  LED Ceiling Lightings    NaN
# 23329  LED Ceiling Lightings    NaN
# 23330  LED Ceiling Lightings    NaN
# 23331  LED Ceiling Lightings    NaN
# 23332  LED Ceiling Lightings    NaN
# 23376            Table Lamps    NaN
# 23377            Table Lamps    NaN
# 39125            Floor Lamps    NaN
# 45230  LED Ceiling Lightings    NaN
# 45231  LED Ceiling Lightings    NaN
# 47219         Ceiling Lights    NaN
# 47914            Table Lamps    NaN
# 47915            Table Lamps    NaN
# 48922         Ceiling Lights    NaN
# 49414            Wall Lights    NaN
# 49535            Table Lamps    NaN
# 49538            Table Lamps    NaN
# 49541         Ceiling Lights    NaN
# 49542         Ceiling Lights    NaN
# 49939            Table Lamps    NaN
# 49942            Table Lamps    NaN

# %%
products_df_b['name_x'].value_counts(dropna=False)
# Out:
# NaN         21486
# 패브릭          4575
# 책상/테이블       3766
# 조명           3019
# 의자/스툴        2993
# 소파           2230
# 가전           2040
# 수납가구         2035
# 책장/선반        1935
# 화장대/거울       1070
# Kitchen       983
# 드레스룸/행거       907
# 파티션/구조물       680
# 생활/운동         632
# 주방싱크/욕실       526
# 반려동물          410
# Décor         326
# 유아동가구         273
# Bathroom       87
# 침대/매트리스        60
# Lighting       39
# Chairs         31
# Tables         17
# Sofas          14
# Storage         9
# Name: name_x, dtype: int64

# %%
products_df_b['name_y'].value_counts(dropna=False).index.tolist()
# Out:
# [nan,
#  '커튼',
#  '일반의자',
#  'TV',
#  '장스탠드',
#  '카페트/러그',
#  '단스탠드',
#  '식탁',
#  '책장',
#  '책상',
#  '협탁/사이드테이블',
#  '에어컨',
#  '학생/오피스의자',
#  '3인용소파',
#  '블라인드/롤스크린',
#  '스탠드선반',
#  '수납장',
#  '생활',
#  'Kitchen Cabinet Set',
#  '소파테이블',
#  '파티션',
#  '4인용/다인용소파',
#  '전신거울',
#  'TV장',
#  '서랍장',
#  '무드등/장식조명',
#  '행거',
#  '벽선반',
#  '2인용소파',
#  '옷장',
#  '쿠션/방석',
#  '주방수납/렌지대',
#  '1인용소파',
#  '진열장/장식장',
#  '싱크(상부장/하부장)',
#  '벽조명',
#  '홈바/아일랜드식탁',
#  '고양이',
#  '일반화장대',
#  '강아지',
#  '바체어',
#  '후드',
#  '탁상거울',
#  '침구',
#  '벽거울',
#  '리클라이너소파',
#  'Base Cabinets',
#  '벤치',
#  '이동식선반/트롤리',
#  '매트',
#  '콘솔',
#  '좌식/접이식테이블',
#  'Wall Cabinets',
#  '붙박이장',
#  '드레스룸',
#  '소파스툴',
#  '빈백소파',
#  '유아동수납',
#  '게이밍의자',
#  '소파베드',
#  '음향/영상가전',
#  '유아동놀이가구외',
#  'Frames & Photos',
#  '오피스',
#  '신발장',
#  '유아동소파/의자',
#  'Books & Organisation',
#  'Sinks',
#  '욕실 악세사리',
#  '좌식의자',
#  'Flowers & Plants',
#  '벙커/이층침대',
#  'Range Hoods',
#  'Toilets',
#  '아트월',
#  '욕조&샤워',
#  '좌식화장대',
#  '유아동침대',
#  'Cushions',
#  '운동',
#  '좌식소파',
#  '유아동책상/테이블',
#  'Objet',
#  '기둥',
#  'Kitchen Accessories',
#  'Bathroom Cabinets',
#  'Dining Chairs',
#  'Kitchen Islands',
#  'Rugs',
#  '세면대',
#  'Curtains',
#  'Bathroom Sinks',
#  'LED Ceiling Lightings',
#  '변기',
#  '계단',
#  'Vase & Pottery',
#  'Ceiling Lights',
#  'Bedding',
#  'Kids',
#  'Shower Partitions',
#  'Clothes & Towels',
#  'Candle & Diffuser',
#  'Basket & Bin',
#  '패밀리침대',
#  'Table Lamps',
#  '모션베드',
#  'Cabinets',
#  'Armchairs (One-seat Sofas)',
#  'Wall Lights',
#  'Stools & Bar Chairs',
#  'Two-seat Sofas',
#  'Mobile',
#  'Desks',
#  'Side Tables',
#  'Seating pads',
#  'Coffee Tables',
#  'Bathroom Accessories',
#  'Mirrors',
#  'Food',
#  'Office Chairs',
#  'TV Stands',
#  'Dining Tables',
#  'Shelves',
#  'Floor Lamps',
#  'Three-seat Sofas']

# %%
for item_name in products_df_4.name.tolist():
    if '의자' in item_name:
        print(item_name)
        break
# Out:
# 또띠 인테리어 체어 의자 (화이트)

# %%
# qval=None => 아이템과 유사한 카테고리의 결과 추천 / qval=int => 아이템과 비슷한 스타일의 다른 아이템 추천(기존 전문가 셋을 기반)
search_engine_4 = SEARCH_RECOMMEND(products_df_4, qval=None)

# %%
prod = "또띠 인테리어 체어 의자 (화이트)"
search_engine_4.search_product(prod, topn=10)
# Out:
# 사용자 님의 아이템 목록에 [또띠 인테리어 체어 의자 (화이트)]를 추가합니다.
# 사용자 님이 현재 선택한 아이템 목록 : {'XxzI_YtF23C4A4371F5472C'}
# 검색 아이템이 해당한 프로젝트 ID : X8leUtv16A82EFBBF284125
# 검색 태그 : modern 파란들가구 또띠 인테리어 체어 의자 (화이트) x8leutv16a82efbbf284125
# 검색 시간 : 0.0898초
#
# 의자/스툴
# 사용자가 선택한 아이템 : 또띠 인테리어 체어 의자 (화이트)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=500x500 at 0x1682D896580>
# ================================================================================
# 추천 아이템 Top10
# ================================================================================
# 추천 1순위 : 팬톤 체어 (화이트)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=500x500 at 0x1682FEB6190>
# ------------------------------------------------------------
# 추천 2순위 : 아마레 식탁의자 (화이트)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=500x500 at 0x1682D896EE0>
# ------------------------------------------------------------
# 추천 3순위 : 위더스 멀티책상 1460 화이트에디션 (화이트)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=500x500 at 0x1682FEB6220>
# ------------------------------------------------------------
# 추천 4순위 : 티 체어 오크 (화이트)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=500x500 at 0x1682D8967C0>
# ------------------------------------------------------------
# 추천 5순위 : 팬톤 체어 (블랙)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=500x500 at 0x1682FEB60D0>
# ------------------------------------------------------------
# 추천 6순위 : Book
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=500x500 at 0x1682D896A60>
# ------------------------------------------------------------
# 추천 7순위 : sketching
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=500x500 at 0x1682D896160>
# ------------------------------------------------------------
# 추천 8순위 : 팬톤 체어 (클래식 레드)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=500x500 at 0x1682FEB6F70>
# ------------------------------------------------------------
# 추천 9순위 : 팬톤 체어 (소프트 민트)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=500x500 at 0x1682D8967C0>
# ------------------------------------------------------------
# 추천 10순위 : 대형 떡갈고무나무 인테리어 식물 (화이트)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=500x500 at 0x1682D896EE0>
# ------------------------------------------------------------

# %%
search_engine_b.result
# Out:
#    index               product_id                                        name  \
# 0   1858  XnWHmScC2E2A943F20142CA                             무지개 우드 선반 (화이트)
# 1  42334  XuBZpz_84159255E6BA4E04             팅클팝 직사각형 그로잉책상 1200폭(아이보리+키즈블루)
# 2  43157  XuBUk8WE17BC2D43B30445C                   제롬 키즈 모션데스크(핀란드 아이보리+그레이)
# 3  44604  XuBUzJM98587A0E0F144393                 제롬 키즈 모션데스크(핀란드 아이보리+허니옐로우)
# 4  42328  XkM8XkP6954B3624D054A4F                    RF코니 벤치 수납 스툴 1200 (화이트)
# 5   1966  XuBrmedD6D93986E80845E2  구스토 800폭 높은 카페장/홈카페 다용도 주방 수납장(그레이+뉴트럴밤나무)
# 6  43198  XjDwfV73BDE0A27FF444DE9                  트렌드라인 마가렛 7단 와이드 서랍장 (화이트)
# 7  46881  XpB5qA70A966B74BA744B62              NEW 클린트 모던 거실장 120cm 서랍형 (화이트)
# 8  45303  XvJwdI932B73E31591547DE             꼼므 1200 아이 책상+의자2개 세트 2color 핑크
# 9  21427  XgAxrhR919F3930525C440B                           벤치 수납장 1200 (화이트)
#
#                                              new_tag                projectId  \
# 0  modern 선반 벽선반 벽수납 벽걸이선반 벽걸이수납 화이트 흰색 가공목(mdf외)...  X8nOJBP70A4670CF22F4BF6
# 1  natural modern 유아동책상 유아 키즈 아기 아동 책상 테이블 아기책상 화...  X8crL4-19F97711040741FE
# 2  modern 유아동책상 유아 키즈 아기 아동 책상 테이블 아기책상 화이트 흰색 가공...  X8ACbww10A482ED9F4942FD
# 3  modern 유아동책상 유아 키즈 아기 아동 책상 테이블 아기책상 화이트 흰색 가공...  X8PsSFc6252EF89E7144DF4
# 4  modern 벤치 밴치 화이트 흰색 가공목(mdf 외) 가공목 나무 우드 네추럴 네...  X8iEk4y187E7CB835E644E9
# 5  modern 렌지대 주방수납 주방장 주방수납 주방선반 브라운 갈색 가공목(mdf 외...  X8nOJBP70A4670CF22F4BF6
# 6  modern natural 서랍장 서랍 화이트 흰색 가공목(mdf 외) 가공목 나무...  X8f847zF6967B1037E54443
# 7  modern tv장 거실장 티비장 티비다이 다이 tv다이 거실수납장 tv거실장 티비...  X7HwQlc093F2D8650AE4182
# 8  natural modern 유아동책상 유아 키즈 아기 아동 책상 테이블 아기책상 핑...  X8FetN24B61464AD2AB4CE9
# 9  modern 수납장 수납 캐비넷 캐비닛 케비넷 케비닛 화이트 흰색 가공목(mdf 외...  X8vZSLj052A7675D40E4EB4
#
#                                               images name_x     name_y  \
# 0  [https://resources.archisketch.com/product/XnW...  책장/선반        벽선반
# 1  [https://resources.archisketch.com/product/XuB...  유아동가구  유아동책상/테이블
# 2  [https://resources.archisketch.com/product/XuB...  유아동가구  유아동책상/테이블
# 3  [https://resources.archisketch.com/product/XuB...  유아동가구  유아동책상/테이블
# 4  [https://resources.archisketch.com/product/XkM...  의자/스툴         벤치
# 5  [https://resources.archisketch.com/product/XuB...   수납가구   주방수납/렌지대
# 6  [https://resources.archisketch.com/product/XjD...   수납가구        서랍장
# 7  [https://resources.archisketch.com/product/XpB...   수납가구        TV장
# 8  [https://resources.archisketch.com/product/XvJ...  유아동가구  유아동책상/테이블
# 9  [https://resources.archisketch.com/product/XgA...   수납가구        수납장
#
#    similarity
# 0    0.498084
# 1    0.417219
# 2    0.403974
# 3    0.394737
# 4    0.393822
# 5    0.393220
# 6    0.391753
# 7    0.389439
# 8    0.387097
# 9    0.386364

# %%
products_df = DATA.products_json

# %%
products_df['category_name'] = products_df['categories'].apply(lambda x: pd.Series(x)).reset_index(drop=True).drop(columns=1)
# Out:
# /var/folders/9_/rnj5svk11p1157tkdv28yb6r0000gn/T/ipykernel_7540/3170452617.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   products_df['category_name'] = products_df['categories'].apply(lambda x: pd.Series(x)).reset_index(drop=True).drop(columns=1)

# %%
products_df.head(1).T
# Out:
#                                                                   0
# _id                                         X5rPclT9CFB7E73DEA8495A
# name                                                          4F_TV
# modelUrl                                                       None
# enterpriseId                                       15BEED4FED5A48FD
# userId                                             36F2E1069E1140E6
# categories                                [X5sOfKR8EE6E3FB89134354]
# archiCategories                                                  []
# description                                                    None
# tags                                                             []
# brand                                                          None
# sku                                                            None
# alias                                                          None
# legacyName                                                     None
# type                                                              1
# productType                                               FURNITURE
# dimensions        {'width': 4200, 'height': 2800, 'depth': 40, '...
# website                                                        None
# previewImage      https://resources.archisketch.com/product/X5rP...
# images            [https://resources.archisketch.com/product/X5r...
# material                                                       None
# price                                                         0 KRW
# priceInfo                             {'value': 0.0, 'unit': 'KRW'}
# rendered                                                       True
# editorType         {'code': 30, 'name': 'wall item', 'open': False}
# editorAsset       {'twoD': 'https://resources.archisketch.com/pr...
# showInEditor                                                   True
# lockDimensions                                                False
# materialCategory                                               None
# mappingDimension                                               None
# renderValues                                                   None
# color                                                          None
# renderSettings    {'tempararyConfigure': 'config_X5rPeZa.archisk...
# renderMaterial                                                false
# hdViewerImages                                                   []
# ar                {'android': 'https://d2uz6y97crd8bk.cloudfront...
# option                                                         None
# parentProduct                                                  None
# createdAt                                  2022-01-18T03:31:58.832Z
# updatedAt                                  2022-01-18T08:07:45.129Z
# category_name                               X5sOfKR8EE6E3FB89134354

# %%
DATA.products_json[DATA.products_json['_id']=='Xzp1wfM1E662584F0944051']['categories'].values[0][0]
# Out:
# 'XrLuKipFFDA75B2F4B74262'

# %%
DATA.products_b.head()
# Out:
#       enterprise_id        top_style_1 top_style                projectId  \
# 0  B57D4F97C0E44A11          [NATURAL]   NATURAL  X9djPepD57A2BDCD418437C
# 1  B57D4F97C0E44A11          [NATURAL]   NATURAL  X9dU4bb1CF0EE26E341493B
# 2  B57D4F97C0E44A11          [NATURAL]   NATURAL  X9a1taeFAA511E93B794404
# 3  B57D4F97C0E44A11  [MODERN, NATURAL]    MODERN  X8Ao1yi02242EB57CD44E0B
# 4  B57D4F97C0E44A11  [NATURAL, MODERN]   NATURAL  X8MtJveB527ACDC1FE44F66
#
#    awesome_score               product_id  \
# 0       0.993074  XjDwfV4C2377DB2C32B4EBD
# 1       0.983243  XjDwfV4C2377DB2C32B4EBD
# 2       0.893659  XjDwfV4C2377DB2C32B4EBD
# 3       0.839363  XjDwfV4C2377DB2C32B4EBD
# 4       0.981309  XjDwfV4C2377DB2C32B4EBD
#
#                                                 tags                   name  \
# 0  [렌지대, 주방수납, 주방장, 주방선반, 베이지, 가공목(mdf외), 가공목, 나무...  onion 진저 주방 수납장 (내추럴)
# 1  [렌지대, 주방수납, 주방장, 주방선반, 베이지, 가공목(mdf외), 가공목, 나무...  onion 진저 주방 수납장 (내추럴)
# 2  [렌지대, 주방수납, 주방장, 주방선반, 베이지, 가공목(mdf외), 가공목, 나무...  onion 진저 주방 수납장 (내추럴)
# 3  [렌지대, 주방수납, 주방장, 주방선반, 베이지, 가공목(mdf외), 가공목, 나무...  onion 진저 주방 수납장 (내추럴)
# 4  [렌지대, 주방수납, 주방장, 주방선반, 베이지, 가공목(mdf외), 가공목, 나무...  onion 진저 주방 수납장 (내추럴)
#
#                                               images  \
# 0  [https://resources.archisketch.com/product/XjD...
# 1  [https://resources.archisketch.com/product/XjD...
# 2  [https://resources.archisketch.com/product/XjD...
# 3  [https://resources.archisketch.com/product/XjD...
# 4  [https://resources.archisketch.com/product/XjD...
#
#                   categories  use_count            category_name  \
# 0  [XrLr6A621BD36C01A784EB4]         10  XrLr6A621BD36C01A784EB4
# 1  [XrLr6A621BD36C01A784EB4]         10  XrLr6A621BD36C01A784EB4
# 2  [XrLr6A621BD36C01A784EB4]         10  XrLr6A621BD36C01A784EB4
# 3  [XrLr6A621BD36C01A784EB4]         10  XrLr6A621BD36C01A784EB4
# 4  [XrLr6A621BD36C01A784EB4]         10  XrLr6A621BD36C01A784EB4
#
#                        _id name_x    name_y  \
# 0  XrLr6A621BD36C01A784EB4   수납가구  주방수납/렌지대
# 1  XrLr6A621BD36C01A784EB4   수납가구  주방수납/렌지대
# 2  XrLr6A621BD36C01A784EB4   수납가구  주방수납/렌지대
# 3  XrLr6A621BD36C01A784EB4   수납가구  주방수납/렌지대
# 4  XrLr6A621BD36C01A784EB4   수납가구  주방수납/렌지대
#
#                                              new_tag
# 0  natural 렌지대 주방수납 주방장 주방선반 베이지 가공목(mdf외) 가공목 나무...
# 1  natural 렌지대 주방수납 주방장 주방선반 베이지 가공목(mdf외) 가공목 나무...
# 2  natural 렌지대 주방수납 주방장 주방선반 베이지 가공목(mdf외) 가공목 나무...
# 3  modern natural 렌지대 주방수납 주방장 주방선반 베이지 가공목(mdf외)...
# 4  natural modern 렌지대 주방수납 주방장 주방선반 베이지 가공목(mdf외)...

# %%
# category['children'] -> name(label) 
def find_category_df(category):
    df = pd.DataFrame()
    for i in category['children']:
        df2 = pd.DataFrame(i)
        df = pd.concat([df, df2])
    return df

# %%
cat_a = find_category_df(DATA.category_json)
cat_a
# Out:
#                         _id              name      enterpriseId  \
# 0          1633637E83634380             Doors  421B6D0E746C4E6D
# 1          B8A92E293E4E4047           Windows  421B6D0E746C4E6D
# 2          D70A7F6A83794317   Other Materials  421B6D0E746C4E6D
# 0          7938684E15E143D6     Refrigerators  421B6D0E746C4E6D
# 1          97E89A79A2D549D6  Air Conditioners  421B6D0E746C4E6D
# ..                      ...               ...               ...
# 0   XrLtsdV9371C959478A4D04             유아동침대  B57D4F97C0E44A11
# 1   XrLtuH-7E461B9CB6CB464F          유아동소파/의자  B57D4F97C0E44A11
# 2   XrLtvzp2501BDC3011741BC             유아동수납  B57D4F97C0E44A11
# 3   XrLtxCDAEC74F8C38D6434B         유아동책상/테이블  B57D4F97C0E44A11
# 4   XrLtz0F7BCB02C449144E4A          유아동놀이가구외  B57D4F97C0E44A11
#
#                                              children  \
# 0   [{'_id': '83D507B20A56479F', 'name': 'Swing Do...
# 1   [{'_id': '7D73016B30CC43F9', 'name': 'Swing Wi...
# 2   [{'_id': 'AF6BCC66E8014F7B', 'name': 'Columns'...
# 0   [{'_id': 'DCAAC2FE131344DD', 'name': 'Refriger...
# 1   [{'_id': '72DAF61594364EC2', 'name': 'Floor A/...
# ..                                                ...
# 0   [{'_id': 'Xti4gwm06CEE7D9C67F4070', 'name': 'N...
# 1   [{'_id': 'Xti4ivw212B745EAB014041', 'name': 'N...
# 2   [{'_id': 'Xti4j2E1809CA54B3914C22', 'name': 'N...
# 3   [{'_id': 'Xti4lBBCE5460A7866A46AD', 'name': 'N...
# 4   [{'_id': 'Xti4l8O41F34F30F263424E', 'name': 'N...
#
#                                                 image  \
# 0   https://resources.archisketch.com/enterprises/...
# 1   https://resources.archisketch.com/enterprises/...
# 2   https://resources.archisketch.com/enterprises/...
# 0   https://resources.archisketch.com/enterprises/...
# 1   https://resources.archisketch.com/enterprises/...
# ..                                                ...
# 0   https://resources.archisketch.com/enterprises/...
# 1   https://resources.archisketch.com/enterprises/...
# 2   https://resources.archisketch.com/enterprises/...
# 3   https://resources.archisketch.com/enterprises/...
# 4   https://resources.archisketch.com/enterprises/...
#
#                    parentId                 createdAt  \
# 0          D0618DD3D2AD4ACF  2020-01-28T04:57:38.038Z
# 1          D0618DD3D2AD4ACF  2020-01-28T04:58:18.274Z
# 2          D0618DD3D2AD4ACF  2020-01-28T05:13:58.091Z
# 0          C5056ABD01F84CB8  2020-01-23T01:06:28.326Z
# 1          C5056ABD01F84CB8  2020-01-23T01:06:28.326Z
# ..                      ...                       ...
# 0   XrLszCv9134EC572B724DF2  2021-07-22T00:56:31.317Z
# 1   XrLszCv9134EC572B724DF2  2021-07-22T00:56:38.142Z
# 2   XrLszCv9134EC572B724DF2  2021-07-22T00:56:45.033Z
# 3   XrLszCv9134EC572B724DF2  2021-07-22T00:56:50.051Z
# 4   XrLszCv9134EC572B724DF2  2021-07-22T00:57:01.445Z
#
#                    updatedAt
# 0   2021-06-25T02:37:33.522Z
# 1   2021-03-29T05:44:06.625Z
# 2   2021-06-25T02:36:56.262Z
# 0   2021-01-27T04:45:25.209Z
# 1   2020-07-16T05:17:33.508Z
# ..                       ...
# 0   2021-09-06T06:54:58.739Z
# 1   2021-09-06T06:55:22.896Z
# 2   2021-09-06T06:55:35.101Z
# 3   2021-09-06T06:55:50.271Z
# 4   2021-09-06T06:56:51.375Z
#
# [189 rows x 8 columns]

# %%
cat_a[cat_a['_id'] == 'XrLuKipFFDA75B2F4B74262']
# Out:
# Empty DataFrame
# Columns: [_id, name, enterpriseId, children, image, parentId, createdAt, updatedAt]
# Index: []

# %%
prod_a = pd.merge(products_df[['_id', 'name', 'category_name']], 
         cat_a[['name', '_id', 'enterpriseId']], 
         left_on='category_name', right_on='_id', how='left')

# %%
cat_b = find_category_df(cat_a)
cat_b.head()
# Out:
#                 _id           name      enterpriseId  \
# 0  83D507B20A56479F    Swing Doors  421B6D0E746C4E6D
# 1  AE5BFBA2DE9F439B  Sliding Doors  421B6D0E746C4E6D
# 2  FA0D229869E34AEF  Folding Doors  421B6D0E746C4E6D
# 3  4F088FF30DF04594   Garage Doors  421B6D0E746C4E6D
# 0  7D73016B30CC43F9  Swing Windows  421B6D0E746C4E6D
#
#                                                image          parentId  \
# 0  https://resources.archisketch.com/enterprises/...  1633637E83634380
# 1  https://resources.archisketch.com/enterprises/...  1633637E83634380
# 2  https://resources.archisketch.com/enterprises/...  1633637E83634380
# 3  https://resources.archisketch.com/enterprises/...  1633637E83634380
# 0  https://resources.archisketch.com/enterprises/...  B8A92E293E4E4047
#
#       grandparentId                 createdAt                 updatedAt
# 0  D0618DD3D2AD4ACF  2020-01-28T05:00:37.293Z  2020-02-04T08:21:41.079Z
# 1  D0618DD3D2AD4ACF  2020-01-28T05:01:46.053Z  2020-02-04T08:22:01.978Z
# 2  D0618DD3D2AD4ACF  2020-01-28T05:07:15.234Z  2020-02-04T08:22:25.474Z
# 3  D0618DD3D2AD4ACF  2020-01-28T05:11:12.445Z  2021-06-25T02:37:33.522Z
# 0  D0618DD3D2AD4ACF  2020-01-28T05:11:59.987Z  2020-02-04T08:23:15.345Z

# %%
prod_b = pd.merge(products_df[['_id', 'name', 'category_name']], 
         cat_b[['name', '_id', 'enterpriseId']], 
         left_on='category_name', right_on='_id', how='left')

# %%
prod_a.sort_values(by='_id_x').head()
# Out:
#                  _id_x                                 name_x  \
# 490   002E454FDD8D4D01  호텔식 더뷰 암막커튼 9colors (창문형/긴창형) (마블그레이)
# 20    0033BB725EF54736                    투명 식물 액자 - 야자 A3사이즈
# 138   009215254E844EE9                          밤부 티슈 케이스 106
# 6663  00E53B958EA24EBF           위더스 컴퓨터책상 1260 2colors (티/화)
# 239   00F723402D634E1F                       선데이 러그 특대형 (그레이)
#
#                 category_name    name_y                    _id_y  \
# 490   XrMYTHY9CB40FCFDDC14991        커튼  XrMYTHY9CB40FCFDDC14991
# 20    XuaCpKo3531C7175AC44FF3       NaN                      NaN
# 138   XuaCriaC3DD13E894674BEF       NaN                      NaN
# 6663  XrM7nN5EA9A10A8E476454A  무드등/장식조명  XrM7nN5EA9A10A8E476454A
# 239   XrMYNApF08F061085254CB7    카페트/러그  XrMYNApF08F061085254CB7
#
#           enterpriseId
# 490   B57D4F97C0E44A11
# 20                 NaN
# 138                NaN
# 6663  B57D4F97C0E44A11
# 239   B57D4F97C0E44A11

# %%
prod_b.sort_values(by='_id_x').head()
# Out:
#                  _id_x                                 name_x  \
# 490   002E454FDD8D4D01  호텔식 더뷰 암막커튼 9colors (창문형/긴창형) (마블그레이)
# 20    0033BB725EF54736                    투명 식물 액자 - 야자 A3사이즈
# 138   009215254E844EE9                          밤부 티슈 케이스 106
# 6663  00E53B958EA24EBF           위더스 컴퓨터책상 1260 2colors (티/화)
# 239   00F723402D634E1F                       선데이 러그 특대형 (그레이)
#
#                 category_name  name_y                    _id_y  \
# 490   XrMYTHY9CB40FCFDDC14991     NaN                      NaN
# 20    XuaCpKo3531C7175AC44FF3  벽/천장장식  XuaCpKo3531C7175AC44FF3
# 138   XuaCriaC3DD13E894674BEF  인테리어소품  XuaCriaC3DD13E894674BEF
# 6663  XrM7nN5EA9A10A8E476454A     NaN                      NaN
# 239   XrMYNApF08F061085254CB7     NaN                      NaN
#
#           enterpriseId
# 490                NaN
# 20    B57D4F97C0E44A11
# 138   B57D4F97C0E44A11
# 6663               NaN
# 239                NaN

# %%
len(prod_a), len(prod_b)
# Out:
# (9515, 9515)

# %%
pd.concat([prod_a.rename(columns={'name_y':'category_a'}), 
           prod_b[['name_y']].rename(columns={'name_y':'category_b'})], axis=1)
# Out:
#                         _id_x                                        name_x  \
# 0     X5rPclT9CFB7E73DEA8495A                                         4F_TV
# 1     Xo7kQN3DC7A5B7C9FE746D6                           스마트 라인 LED (화이트)_on
# 2     XtxfYC1EF0F9090248B4518                              브로 사계절 인테리어 러그 S
# 3     XSWNaDQ8D34AB5317CA4971                                      맥북프로 13형
# 4     XT21RHb69DF906D42DF4284                           원터치 와이드 화이트 휴지통 10L
# ...                       ...                                           ...
# 9510  XdGlxwz9246FC25CD404DE4                     비올렛 디자인체어 2colors (월넛브라운)
# 9511  XvJtJWPA51ACB9F262E4019                               모뜨 3단 서랍장 (화이트)
# 9512  XhJp_eJBCFF598127BE4AD8  사무용/컴퓨터 메쉬의자 801 화이트프레임 HEAD(포켓스프링 방석) (그레이)
# 9513  Xz-wAFDFF8B0AABAE3B444D           프리미엄 블루투스 홈오디오 모델 XL Model XL (화이트)
# 9514  XxzI_Y6ABD33F648B514ADC     번드 모어 리놀륨 리빙다이닝 4인 코너형 테이블소파 SET L형 (머쉬룸)
#
#                 category_name             category_a                    _id_y  \
# 0     X5sOfKR8EE6E3FB89134354                    NaN                      NaN
# 1     Xo20nqI91CAA7647AA149EF  LED Ceiling Lightings  Xo20nqI91CAA7647AA149EF
# 2            10D4B42437844E42                   Rugs         10D4B42437844E42
# 3            1348D5C358224276                    NaN                      NaN
# 4     XrNAUjE123731FDC5D847C0                     생활  XrNAUjE123731FDC5D847C0
# ...                       ...                    ...                      ...
# 9510  XrLsP5FB1A8CBA8FF744780                     식탁  XrLsP5FB1A8CBA8FF744780
# 9511  XrLs2vMD1BC5D9B32664A60                   일반의자  XrLs2vMD1BC5D9B32664A60
# 9512  XrLrsOTDB80B92F9B9D440E                    서랍장  XrLrsOTDB80B92F9B9D440E
# 9513  XrLs4Lm51A52E3EE5094BE3               학생/오피스의자  XrLs4Lm51A52E3EE5094BE3
# 9514  Xt16pQ0FD730DDB60B042BF                    NaN                      NaN
#
#           enterpriseId           category_b
# 0                  NaN                  NaN
# 1     421B6D0E746C4E6D                  NaN
# 2     421B6D0E746C4E6D                  NaN
# 3                  NaN  Laptops & Portables
# 4     B57D4F97C0E44A11                  NaN
# ...                ...                  ...
# 9510  B57D4F97C0E44A11                  NaN
# 9511  B57D4F97C0E44A11                  NaN
# 9512  B57D4F97C0E44A11                  NaN
# 9513  B57D4F97C0E44A11                  NaN
# 9514               NaN              스피커/라디오
#
# [9515 rows x 7 columns]
