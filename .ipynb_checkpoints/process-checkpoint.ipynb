# %%
import json
import pandas as pd
import numpy as np
from time import time
from glob import glob

# %%
# abs path -> 22-03-07/ *.json
best = glob('22-03-07/best*.json')
item = glob('22-03-07/item*.json')
products = glob('22-03-07/products*.json')
#category1 == category2 = True
category = glob('22-03-07/category1.json')

# %%
import pandas as pd
import json

class Preprocess:
    
    def __init__(self, best, item, products, category, style_ths=0.1):
        """
        style_ths : top_style_predictions 에서 범위 조절 (e.g. 0.1 이상으로 예측 점수를 받은 스타일만 받아옴 - maximum 3개)
        """
        self.style_ths = style_ths
        self.style_ths_name = str(style_ths)[-1]
        
        self.best = best
        self.item = item
        self.products = products
        self.category = category
        
        self.best_json = self.read_json(best)
        self.item_json = self.read_json(item)
        self.products_json = self.read_json(products).drop_duplicates('_id') # products json duplicated deleted
        self.category_json = self.read_json2(category).reset_index(drop=True)
        self.best_item, self.category,self.products_4, self.products_b = self.preprocess(self.best_json, 
                                                                           self.item_json, 
                                                                           self.products_json, 
                                                                           self.category_json)

    def read_json(self,json_file):
        df = pd.DataFrame()
        if json_file != self.products:  
            for file in json_file:
                x = pd.read_json(file)
                df = pd.concat([df, x])
        else:
            # why -> products json duplicated 
            for file in json_file:
                x = pd.read_json(file).T.reset_index(drop=True)    
                df = pd.concat([df, x])
        return df

    def read_json2(self,category):
        for i in category:
            with open(i) as js:
                json_data = json.load(js)
        cat_4, cat_b = pd.DataFrame(json_data['421B6D0E746C4E6D']), pd.DataFrame(json_data['B57D4F97C0E44A11'])
        category = pd.concat([cat_4, cat_b])
        return category
    
    def get_productId(self, items_list):
        new_list = []
        for item in items_list:
            new_list.append(item['productId'])
        return new_list
    
    # category['children'] -> name(label) 
    def find_category_df(self, category):
        df = pd.DataFrame()
        for i in category['children']:
            df2 = pd.DataFrame(i)
            df = pd.concat([df, df2])
        return df
        
    def preprocess(self, best, item, products, category):
        
        item.rename(columns={'enterpriseId':'enterprise_id', '_id':'id'}, inplace=True)
        templates = pd.merge(best, item, on=['enterprise_id', 'projectId', 'id'])
        
        # 2 enterprise id 
        ent2, ent1 = templates['enterprise_id'].unique().tolist()
        
        # get item_id 
        templates['items'] = templates['items'].apply(self.get_productId)
        
        # find_category_id_preprocess
    
        # edit new columns style_name, style_score > 0.1 
        templates[f'top_style_{self.style_ths_name}'] = templates['style_predictions'].apply(lambda x: sorted([(name, score) for name, score in x.items() if score > self.style_ths], key=lambda x: x[1], reverse=True)[:3])
        # del list, style score
        templates[f'top_style_{self.style_ths_name}'] = templates[f'top_style_{self.style_ths_name}'].apply(lambda x: [name for name, score in x])
        # Edit best_item['items'] = list(values) -> values
        items_stack = pd.DataFrame(templates['items'].apply(lambda x: pd.Series(x)).stack()).reset_index(1, drop=True) 
        products_df = pd.merge(templates[['enterprise_id', 
                                          f'top_style_{self.style_ths_name}', 
                                          'top_style', 
                                          'projectId', 
                                          'awesome_score']].reset_index(), 
                               items_stack.reset_index(), 
                               on='index').drop(['index'], axis=1).rename(columns = {0:'product_id'})
        prod_tags_df = products[['_id', 'tags', 'name', 'images', 'categories']]
        products_df = pd.merge(products_df, 
                               prod_tags_df, 
                               left_on='product_id', 
                               right_on='_id').drop(['_id'], axis=1)
        products_df = pd.merge(products_df, 
                               products_df['product_id'].value_counts().reset_index(),
                               left_on='product_id',
                               right_on='index').rename(columns = {'product_id_x': 'product_id',
                                                                   'product_id_y':'use_count'}).drop(['index'], axis=1)
        
        # category[categories] = list(values) -> values
        products_df['category_name'] = products_df['categories'].apply(lambda x: pd.Series(x)).reset_index(drop=True).drop(columns=1)
        
        # find_category_id_preprocess
        cat_df = self.find_category_df(self.category_json) 
        cat_df2 = self.find_category_df(cat_df)
        self.products_json['category_name'] = self.products_json['categories'].apply(lambda x: pd.Series(x)).reset_index(drop=True).drop(columns=1)
        # category_df['name_x'] = category['children']
        # category_df['name_y'] = category['children'][children]
        prod_a = pd.merge(self.products_json,
                          cat_df[['name', '_id', 'enterpriseId']],
                          left_on='category_name', right_on='_id', how='left').sort_values(by='_id_x')
        
        prod_b = pd.merge(self.products_json,
                          cat_df2[['name', '_id', 'enterpriseId']],
                          left_on='category_name', right_on='_id', how='left').sort_values(by='_id_x')
        
        category_df = pd.concat([prod_a.rename(columns={'name_y':'category_a'}),
                                 prod_b[['name_y']].rename(columns={'name_y':'category_b'})],axis=1)
        
        category_df = pd.merge(self.products_json[['_id', 'name', 'tags', 'dimensions', 'images']], 
                               category_df[['_id_x', 'category_a', 'category_b']], 
                               left_on ='_id', 
                               right_on = '_id_x').drop(['_id_x'], axis=1)
        
        products_df = pd.merge(products_df[['enterprise_id', 'projectId', 'top_style_1', 
                                            'top_style', 'awesome_score', 'product_id', 'use_count']], 
                               category_df, 
                               left_on='product_id', 
                               right_on='_id').drop(['_id'], axis=1)
        
        products_df_4 = products_df[products_df['enterprise_id'] == ent1].reset_index(drop=True)
        products_df_b = products_df[products_df['enterprise_id'] == ent2].reset_index(drop=True)
        
        return templates,category_df, products_df_4, products_df_b

# %%
x = Preprocess(best, item, products, category)
# Out:
# C:\Users\jumpx\AppData\Local\Temp\ipykernel_16028\4135308000.py:80: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   items_stack = pd.DataFrame(templates['items'].apply(lambda x: pd.Series(x)).stack()).reset_index(1, drop=True)
# C:\Users\jumpx\AppData\Local\Temp\ipykernel_16028\4135308000.py:87: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   products_df['category_name'] = products_df['categories'].apply(lambda x: pd.Series(x)).reset_index(drop=True).drop(columns=1)
# C:\Users\jumpx\AppData\Local\Temp\ipykernel_16028\4135308000.py:94: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.products_json['category_name'] = self.products_json['categories'].apply(lambda x: pd.Series(x)).reset_index(drop=True).drop(columns=1)

# %%
x.products_4
# Out:
#          enterprise_id                            top_style_1 top_style  \
# 0     421B6D0E746C4E6D                      [MODERN, NATURAL]    MODERN
# 1     421B6D0E746C4E6D                               [MODERN]    MODERN
# 2     421B6D0E746C4E6D                 [MODERN, SCANDINAVIAN]    MODERN
# 3     421B6D0E746C4E6D                               [MODERN]    MODERN
# 4     421B6D0E746C4E6D                               [MODERN]    MODERN
# ...                ...                                    ...       ...
# 4769  421B6D0E746C4E6D                      [MODERN, NATURAL]    MODERN
# 4770  421B6D0E746C4E6D                      [MODERN, NATURAL]    MODERN
# 4771  421B6D0E746C4E6D                      [MODERN, NATURAL]    MODERN
# 4772  421B6D0E746C4E6D  [MODERN, NATURAL, MID_CENTURY_MODERN]    MODERN
# 4773  421B6D0E746C4E6D  [MODERN, NATURAL, MID_CENTURY_MODERN]    MODERN
#
#                     projectId  awesome_score               product_id  \
# 0     X9IceC_16DC38C091A6439F       0.984499         6E3531E25BF343BE
# 1     X5WaEry9CEC543A4961492E       0.987451  XYW9sOc9CC9CD1261C74F5E
# 2     X3cjAHq297A348CEE5B4698       0.904893         9685F6318BD040E1
# 3     X8HTtd3A494EC74B8EA45A3       0.956234         9685F6318BD040E1
# 4     X4kGJoQA6F0C0CB39874510       0.902196         9685F6318BD040E1
# ...                       ...            ...                      ...
# 4769  X4RwILN6A20B3B4241C4085       0.921340  XhoyNTc39A13BED86BD4F79
# 4770  X4RwILN6A20B3B4241C4085       0.921340  XoeB5AN55133C37EFF84438
# 4771  X4RwILN6A20B3B4241C4085       0.921340  XoTRw3A83567968A2B74D99
# 4772  X4RwILN6A20B3B4241C4085       0.968451  XYizLmP9FA925D538DA4079
# 4773  X4RwILN6A20B3B4241C4085       0.968451  XZGbpZk17B0CA99E7B243BE
#
#                                                  tags_x  \
# 0                                                    []
# 1     [조명, 무드등/장식조명, 무드등, 무드, 브라운, 갈색, 무드등/수면등, 무드등,...
# 2                               [커튼, 데코뷰, 호텔식, 화이트, 시폰]
# 3                               [커튼, 데코뷰, 호텔식, 화이트, 시폰]
# 4                               [커튼, 데코뷰, 호텔식, 화이트, 시폰]
# ...                                                 ...
# 4769                                                 []
# 4770                      [모스카토, Moscato, 스파클링, 스파클링와인]
# 4771                                                 []
# 4772  [침대, 베드, 일반형침대, 일반형, 일반침대, 브라운, 갈색, 원목, 내추럴, 나...
# 4773  [책장, 책꽂이, 북선반, 책, 책꽃이, 베이지, 가공목(mdf외), 가공목, 나무...
#
#                                       name_x  \
# 0                      투명 식물 액자 - 몬스테라 A3사이즈
# 1                           우리집 속 불멍 벽난로 무드등
# 2                              호텔식 화이트 시폰 커튼
# 3                              호텔식 화이트 시폰 커튼
# 4                              호텔식 화이트 시폰 커튼
# ...                                      ...
# 4769                        몬스테라_우드 스탠드화분(중)
# 4770                           모스카토 스위트 스파클링
# 4771                                     와인잔
# 4772        마리카 아카시아 원목침대 2colors (SS) (내추럴)
# 4773  DIY 가로 폭조절 2단 책장 미니 수납장 (3colors) (우드)
#
#                                                images_x  \
# 0     [https://resources.archisketch.com/product/6E3...
# 1     [https://resources.archisketch.com/product/XYW...
# 2     [https://resources.archisketch.com/product/968...
# 3     [https://resources.archisketch.com/product/968...
# 4     [https://resources.archisketch.com/product/968...
# ...                                                 ...
# 4769  [https://resources.archisketch.com/product/Xho...
# 4770  [https://resources.archisketch.com/product/Xoe...
# 4771  [https://resources.archisketch.com/product/XoT...
# 4772  [https://resources.archisketch.com/product/XYi...
# 4773  [https://resources.archisketch.com/product/XZG...
#
#                      categories  ...                      _id  \
# 0     [XuaCpKo3531C7175AC44FF3]  ...         6E3531E25BF343BE
# 1     [XrM7nN5EA9A10A8E476454A]  ...  XYW9sOc9CC9CD1261C74F5E
# 2     [XrMYTHY9CB40FCFDDC14991]  ...         9685F6318BD040E1
# 3     [XrMYTHY9CB40FCFDDC14991]  ...         9685F6318BD040E1
# 4     [XrMYTHY9CB40FCFDDC14991]  ...         9685F6318BD040E1
# ...                         ...  ...                      ...
# 4769         [35639963DFE14DAE]  ...  XhoyNTc39A13BED86BD4F79
# 4770  [Xoxn39o2E16F00AB2024ED3]  ...  XoeB5AN55133C37EFF84438
# 4771  [Xoxn39o2E16F00AB2024ED3]  ...  XoTRw3A83567968A2B74D99
# 4772  [XrMAoqvC726ACFACD674C33]  ...  XYizLmP9FA925D538DA4079
# 4773  [XrLsboPF147D0010A6C450F]  ...  XZGbpZk17B0CA99E7B243BE
#
#                                       name_y      enterpriseId  \
# 0                      투명 식물 액자 - 몬스테라 A3사이즈  B57D4F97C0E44A11
# 1                           우리집 속 불멍 벽난로 무드등  B57D4F97C0E44A11
# 2                              호텔식 화이트 시폰 커튼  B57D4F97C0E44A11
# 3                              호텔식 화이트 시폰 커튼  B57D4F97C0E44A11
# 4                              호텔식 화이트 시폰 커튼  B57D4F97C0E44A11
# ...                                      ...               ...
# 4769                        몬스테라_우드 스탠드화분(중)  421B6D0E746C4E6D
# 4770                           모스카토 스위트 스파클링  421B6D0E746C4E6D
# 4771                                     와인잔  421B6D0E746C4E6D
# 4772        마리카 아카시아 원목침대 2colors (SS) (내추럴)  B57D4F97C0E44A11
# 4773  DIY 가로 폭조절 2단 책장 미니 수납장 (3colors) (우드)  B57D4F97C0E44A11
#
#                                                  tags_y  \
# 0                                                    []
# 1     [조명, 무드등/장식조명, 무드등, 무드, 브라운, 갈색, 무드등/수면등, 무드등,...
# 2                               [커튼, 데코뷰, 호텔식, 화이트, 시폰]
# 3                               [커튼, 데코뷰, 호텔식, 화이트, 시폰]
# 4                               [커튼, 데코뷰, 호텔식, 화이트, 시폰]
# ...                                                 ...
# 4769                                                 []
# 4770                      [모스카토, Moscato, 스파클링, 스파클링와인]
# 4771                                                 []
# 4772  [침대, 베드, 일반형침대, 일반형, 일반침대, 브라운, 갈색, 원목, 내추럴, 나...
# 4773  [책장, 책꽂이, 북선반, 책, 책꽃이, 베이지, 가공목(mdf외), 가공목, 나무...
#
#                                              dimensions  \
# 0     {'width': 330, 'height': 449, 'depth': 100, 'u...
# 1     {'width': 320, 'height': 390, 'depth': 140, 'u...
# 2     {'width': 3010, 'height': 2331, 'depth': 288, ...
# 3     {'width': 3010, 'height': 2331, 'depth': 288, ...
# 4     {'width': 3010, 'height': 2331, 'depth': 288, ...
# ...                                                 ...
# 4769  {'width': 451, 'height': 691, 'depth': 458, 'u...
# 4770  {'width': 85, 'height': 334, 'depth': 85, 'uni...
# 4771  {'width': 87, 'height': 232, 'depth': 87, 'uni...
# 4772  {'width': 1235, 'height': 990, 'depth': 2150, ...
# 4773  {'width': 760, 'height': 570, 'depth': 236, 'u...
#
#                                                images_y  \
# 0     [https://resources.archisketch.com/product/6E3...
# 1     [https://resources.archisketch.com/product/XYW...
# 2     [https://resources.archisketch.com/product/968...
# 3     [https://resources.archisketch.com/product/968...
# 4     [https://resources.archisketch.com/product/968...
# ...                                                 ...
# 4769  [https://resources.archisketch.com/product/Xho...
# 4770  [https://resources.archisketch.com/product/Xoe...
# 4771  [https://resources.archisketch.com/product/XoT...
# 4772  [https://resources.archisketch.com/product/XYi...
# 4773  [https://resources.archisketch.com/product/XZG...
#
#                         _id_x                                  name_x  \
# 0            6E3531E25BF343BE                   투명 식물 액자 - 몬스테라 A3사이즈
# 1     XYW9sOc9CC9CD1261C74F5E                        우리집 속 불멍 벽난로 무드등
# 2            9685F6318BD040E1                           호텔식 화이트 시폰 커튼
# 3            9685F6318BD040E1                           호텔식 화이트 시폰 커튼
# 4            9685F6318BD040E1                           호텔식 화이트 시폰 커튼
# ...                       ...                                     ...
# 4769  XhoyNTc39A13BED86BD4F79                        몬스테라_우드 스탠드화분(중)
# 4770  XoeB5AN55133C37EFF84438                           모스카토 스위트 스파클링
# 4771  XoTRw3A83567968A2B74D99                                     와인잔
# 4772  XYizLmP9FA925D538DA4079        마리카 아카시아 원목침대 2colors (SS) (내추럴)
# 4773  XZGbpZk17B0CA99E7B243BE  DIY 가로 폭조절 2단 책장 미니 수납장 (3colors) (우드)
#
#              category_a category_b
# 0                   NaN     벽/천장장식
# 1              무드등/장식조명        NaN
# 2                    커튼        NaN
# 3                    커튼        NaN
# 4                    커튼        NaN
# ...                 ...        ...
# 4769                 식탁        NaN
# 4770          홈바/아일랜드식탁        NaN
# 4771                NaN      화병/화분
# 4772  Candle & Diffuser        NaN
# 4773               단스탠드        NaN
#
# [4774 rows x 22 columns]

# %%
len(x.products_4)
# Out:
# 4774

# %%
xy = x.category
xy = xy.set_index('_id')

# %%
yy = x.products_4[['enterprise_id', 'top_style_1', 'top_style', 'projectId',
       'awesome_score', 'product_id', 'tags_x', 'name_x', 'images_x',
       'categories', 'use_count', 'category_name', '_id']]

yy = yy.set_index('category_name')

# %%
yy
# Out:
#                             enterprise_id  \
# category_name
# XuaCpKo3531C7175AC44FF3  421B6D0E746C4E6D
# XrM7nN5EA9A10A8E476454A  421B6D0E746C4E6D
# XrMYTHY9CB40FCFDDC14991  421B6D0E746C4E6D
# XrMYTHY9CB40FCFDDC14991  421B6D0E746C4E6D
# XrMYTHY9CB40FCFDDC14991  421B6D0E746C4E6D
# ...                                   ...
# 35639963DFE14DAE         421B6D0E746C4E6D
# Xoxn39o2E16F00AB2024ED3  421B6D0E746C4E6D
# Xoxn39o2E16F00AB2024ED3  421B6D0E746C4E6D
# XrMAoqvC726ACFACD674C33  421B6D0E746C4E6D
# XrLsboPF147D0010A6C450F  421B6D0E746C4E6D
#
#                                                    top_style_1 top_style  \
# category_name
# XuaCpKo3531C7175AC44FF3                      [MODERN, NATURAL]    MODERN
# XrM7nN5EA9A10A8E476454A                               [MODERN]    MODERN
# XrMYTHY9CB40FCFDDC14991                 [MODERN, SCANDINAVIAN]    MODERN
# XrMYTHY9CB40FCFDDC14991                               [MODERN]    MODERN
# XrMYTHY9CB40FCFDDC14991                               [MODERN]    MODERN
# ...                                                        ...       ...
# 35639963DFE14DAE                             [MODERN, NATURAL]    MODERN
# Xoxn39o2E16F00AB2024ED3                      [MODERN, NATURAL]    MODERN
# Xoxn39o2E16F00AB2024ED3                      [MODERN, NATURAL]    MODERN
# XrMAoqvC726ACFACD674C33  [MODERN, NATURAL, MID_CENTURY_MODERN]    MODERN
# XrLsboPF147D0010A6C450F  [MODERN, NATURAL, MID_CENTURY_MODERN]    MODERN
#
#                                        projectId  awesome_score  \
# category_name
# XuaCpKo3531C7175AC44FF3  X9IceC_16DC38C091A6439F       0.984499
# XrM7nN5EA9A10A8E476454A  X5WaEry9CEC543A4961492E       0.987451
# XrMYTHY9CB40FCFDDC14991  X3cjAHq297A348CEE5B4698       0.904893
# XrMYTHY9CB40FCFDDC14991  X8HTtd3A494EC74B8EA45A3       0.956234
# XrMYTHY9CB40FCFDDC14991  X4kGJoQA6F0C0CB39874510       0.902196
# ...                                          ...            ...
# 35639963DFE14DAE         X4RwILN6A20B3B4241C4085       0.921340
# Xoxn39o2E16F00AB2024ED3  X4RwILN6A20B3B4241C4085       0.921340
# Xoxn39o2E16F00AB2024ED3  X4RwILN6A20B3B4241C4085       0.921340
# XrMAoqvC726ACFACD674C33  X4RwILN6A20B3B4241C4085       0.968451
# XrLsboPF147D0010A6C450F  X4RwILN6A20B3B4241C4085       0.968451
#
#                                       product_id  \
# category_name
# XuaCpKo3531C7175AC44FF3         6E3531E25BF343BE
# XrM7nN5EA9A10A8E476454A  XYW9sOc9CC9CD1261C74F5E
# XrMYTHY9CB40FCFDDC14991         9685F6318BD040E1
# XrMYTHY9CB40FCFDDC14991         9685F6318BD040E1
# XrMYTHY9CB40FCFDDC14991         9685F6318BD040E1
# ...                                          ...
# 35639963DFE14DAE         XhoyNTc39A13BED86BD4F79
# Xoxn39o2E16F00AB2024ED3  XoeB5AN55133C37EFF84438
# Xoxn39o2E16F00AB2024ED3  XoTRw3A83567968A2B74D99
# XrMAoqvC726ACFACD674C33  XYizLmP9FA925D538DA4079
# XrLsboPF147D0010A6C450F  XZGbpZk17B0CA99E7B243BE
#
#                                                                     tags_x  \
# category_name
# XuaCpKo3531C7175AC44FF3                                                 []
# XrM7nN5EA9A10A8E476454A  [조명, 무드등/장식조명, 무드등, 무드, 브라운, 갈색, 무드등/수면등, 무드등,...
# XrMYTHY9CB40FCFDDC14991                            [커튼, 데코뷰, 호텔식, 화이트, 시폰]
# XrMYTHY9CB40FCFDDC14991                            [커튼, 데코뷰, 호텔식, 화이트, 시폰]
# XrMYTHY9CB40FCFDDC14991                            [커튼, 데코뷰, 호텔식, 화이트, 시폰]
# ...                                                                    ...
# 35639963DFE14DAE                                                        []
# Xoxn39o2E16F00AB2024ED3                      [모스카토, Moscato, 스파클링, 스파클링와인]
# Xoxn39o2E16F00AB2024ED3                                                 []
# XrMAoqvC726ACFACD674C33  [침대, 베드, 일반형침대, 일반형, 일반침대, 브라운, 갈색, 원목, 내추럴, 나...
# XrLsboPF147D0010A6C450F  [책장, 책꽂이, 북선반, 책, 책꽃이, 베이지, 가공목(mdf외), 가공목, 나무...
#
#                                                          name_x name_x  \
# category_name
# XuaCpKo3531C7175AC44FF3                   투명 식물 액자 - 몬스테라 A3사이즈    NaN
# XrM7nN5EA9A10A8E476454A                        우리집 속 불멍 벽난로 무드등    NaN
# XrMYTHY9CB40FCFDDC14991                           호텔식 화이트 시폰 커튼    NaN
# XrMYTHY9CB40FCFDDC14991                           호텔식 화이트 시폰 커튼    NaN
# XrMYTHY9CB40FCFDDC14991                           호텔식 화이트 시폰 커튼    NaN
# ...                                                         ...    ...
# 35639963DFE14DAE                               몬스테라_우드 스탠드화분(중)    NaN
# Xoxn39o2E16F00AB2024ED3                           모스카토 스위트 스파클링    NaN
# Xoxn39o2E16F00AB2024ED3                                     와인잔    NaN
# XrMAoqvC726ACFACD674C33        마리카 아카시아 원목침대 2colors (SS) (내추럴)    NaN
# XrLsboPF147D0010A6C450F  DIY 가로 폭조절 2단 책장 미니 수납장 (3colors) (우드)    NaN
#
#                                                                   images_x  \
# category_name
# XuaCpKo3531C7175AC44FF3  [https://resources.archisketch.com/product/6E3...
# XrM7nN5EA9A10A8E476454A  [https://resources.archisketch.com/product/XYW...
# XrMYTHY9CB40FCFDDC14991  [https://resources.archisketch.com/product/968...
# XrMYTHY9CB40FCFDDC14991  [https://resources.archisketch.com/product/968...
# XrMYTHY9CB40FCFDDC14991  [https://resources.archisketch.com/product/968...
# ...                                                                    ...
# 35639963DFE14DAE         [https://resources.archisketch.com/product/Xho...
# Xoxn39o2E16F00AB2024ED3  [https://resources.archisketch.com/product/Xoe...
# Xoxn39o2E16F00AB2024ED3  [https://resources.archisketch.com/product/XoT...
# XrMAoqvC726ACFACD674C33  [https://resources.archisketch.com/product/XYi...
# XrLsboPF147D0010A6C450F  [https://resources.archisketch.com/product/XZG...
#
#                                         categories  use_count  _id
# category_name
# XuaCpKo3531C7175AC44FF3  [XuaCpKo3531C7175AC44FF3]         33  NaN
# XrM7nN5EA9A10A8E476454A  [XrM7nN5EA9A10A8E476454A]         31  NaN
# XrMYTHY9CB40FCFDDC14991  [XrMYTHY9CB40FCFDDC14991]        460  NaN
# XrMYTHY9CB40FCFDDC14991  [XrMYTHY9CB40FCFDDC14991]        460  NaN
# XrMYTHY9CB40FCFDDC14991  [XrMYTHY9CB40FCFDDC14991]        460  NaN
# ...                                            ...        ...  ...
# 35639963DFE14DAE                [35639963DFE14DAE]          1  NaN
# Xoxn39o2E16F00AB2024ED3  [Xoxn39o2E16F00AB2024ED3]          1  NaN
# Xoxn39o2E16F00AB2024ED3  [Xoxn39o2E16F00AB2024ED3]          1  NaN
# XrMAoqvC726ACFACD674C33  [XrMAoqvC726ACFACD674C33]          1  NaN
# XrLsboPF147D0010A6C450F  [XrLsboPF147D0010A6C450F]          1  NaN
#
# [4774 rows x 13 columns]

# %%
def find_category_df(category):
    df = pd.DataFrame()
    for i in category['children']:
        df2 = pd.DataFrame(i)
        df = pd.concat([df, df2])
    return df

df = find_category_df(x.category_json)
df2 = find_category_df(df).drop('parentId', axis=1).rename(columns={'grandparentId':'parentId'})
# dd = pd.concat([df, df2], ignore_index=True)
# dd = pd.merge(x.category[['name', '_id']], dd, left_on='_id', right_on='parentId').rename(columns={'_id_y' : '_id'}).drop(columns=['_id_x'])

# %%
df
# Out:
#                         _id              name      enterpriseId  \
# 0          1633637E83634380             Doors  421B6D0E746C4E6D
# 1          B8A92E293E4E4047           Windows  421B6D0E746C4E6D
# 2          D70A7F6A83794317   Other Materials  421B6D0E746C4E6D
# 0          7938684E15E143D6     Refrigerators  421B6D0E746C4E6D
# 1          97E89A79A2D549D6  Air Conditioners  421B6D0E746C4E6D
# ..                      ...               ...               ...
# 0   XrLtsdV9371C959478A4D04             유아동침대  B57D4F97C0E44A11
# 1   XrLtuH-7E461B9CB6CB464F          유아동소파/의자  B57D4F97C0E44A11
# 2   XrLtvzp2501BDC3011741BC             유아동수납  B57D4F97C0E44A11
# 3   XrLtxCDAEC74F8C38D6434B         유아동책상/테이블  B57D4F97C0E44A11
# 4   XrLtz0F7BCB02C449144E4A          유아동놀이가구외  B57D4F97C0E44A11
#
#                                              children  \
# 0   [{'_id': '83D507B20A56479F', 'name': 'Swing Do...
# 1   [{'_id': '7D73016B30CC43F9', 'name': 'Swing Wi...
# 2   [{'_id': 'AF6BCC66E8014F7B', 'name': 'Columns'...
# 0   [{'_id': 'DCAAC2FE131344DD', 'name': 'Refriger...
# 1   [{'_id': '72DAF61594364EC2', 'name': 'Floor A/...
# ..                                                ...
# 0   [{'_id': 'Xti4gwm06CEE7D9C67F4070', 'name': 'N...
# 1   [{'_id': 'Xti4ivw212B745EAB014041', 'name': 'N...
# 2   [{'_id': 'Xti4j2E1809CA54B3914C22', 'name': 'N...
# 3   [{'_id': 'Xti4lBBCE5460A7866A46AD', 'name': 'N...
# 4   [{'_id': 'Xti4l8O41F34F30F263424E', 'name': 'N...
#
#                                                 image  \
# 0   https://resources.archisketch.com/enterprises/...
# 1   https://resources.archisketch.com/enterprises/...
# 2   https://resources.archisketch.com/enterprises/...
# 0   https://resources.archisketch.com/enterprises/...
# 1   https://resources.archisketch.com/enterprises/...
# ..                                                ...
# 0   https://resources.archisketch.com/enterprises/...
# 1   https://resources.archisketch.com/enterprises/...
# 2   https://resources.archisketch.com/enterprises/...
# 3   https://resources.archisketch.com/enterprises/...
# 4   https://resources.archisketch.com/enterprises/...
#
#                    parentId                 createdAt  \
# 0          D0618DD3D2AD4ACF  2020-01-28T04:57:38.038Z
# 1          D0618DD3D2AD4ACF  2020-01-28T04:58:18.274Z
# 2          D0618DD3D2AD4ACF  2020-01-28T05:13:58.091Z
# 0          C5056ABD01F84CB8  2020-01-23T01:06:28.326Z
# 1          C5056ABD01F84CB8  2020-01-23T01:06:28.326Z
# ..                      ...                       ...
# 0   XrLszCv9134EC572B724DF2  2021-07-22T00:56:31.317Z
# 1   XrLszCv9134EC572B724DF2  2021-07-22T00:56:38.142Z
# 2   XrLszCv9134EC572B724DF2  2021-07-22T00:56:45.033Z
# 3   XrLszCv9134EC572B724DF2  2021-07-22T00:56:50.051Z
# 4   XrLszCv9134EC572B724DF2  2021-07-22T00:57:01.445Z
#
#                    updatedAt
# 0   2021-06-25T02:37:33.522Z
# 1   2021-03-29T05:44:06.625Z
# 2   2021-06-25T02:36:56.262Z
# 0   2021-01-27T04:45:25.209Z
# 1   2020-07-16T05:17:33.508Z
# ..                       ...
# 0   2021-09-06T06:54:58.739Z
# 1   2021-09-06T06:55:22.896Z
# 2   2021-09-06T06:55:35.101Z
# 3   2021-09-06T06:55:50.271Z
# 4   2021-09-06T06:56:51.375Z
#
# [189 rows x 8 columns]

# %%
df2
# Out:
#                         _id           name      enterpriseId  \
# 0          83D507B20A56479F    Swing Doors  421B6D0E746C4E6D
# 1          AE5BFBA2DE9F439B  Sliding Doors  421B6D0E746C4E6D
# 2          FA0D229869E34AEF  Folding Doors  421B6D0E746C4E6D
# 3          4F088FF30DF04594   Garage Doors  421B6D0E746C4E6D
# 0          7D73016B30CC43F9  Swing Windows  421B6D0E746C4E6D
# ..                      ...            ...               ...
# 0   Xti4gwm06CEE7D9C67F4070            NEW  B57D4F97C0E44A11
# 0   Xti4ivw212B745EAB014041            NEW  B57D4F97C0E44A11
# 0   Xti4j2E1809CA54B3914C22            NEW  B57D4F97C0E44A11
# 0   Xti4lBBCE5460A7866A46AD            NEW  B57D4F97C0E44A11
# 0   Xti4l8O41F34F30F263424E            NEW  B57D4F97C0E44A11
#
#                                                 image  \
# 0   https://resources.archisketch.com/enterprises/...
# 1   https://resources.archisketch.com/enterprises/...
# 2   https://resources.archisketch.com/enterprises/...
# 3   https://resources.archisketch.com/enterprises/...
# 0   https://resources.archisketch.com/enterprises/...
# ..                                                ...
# 0   https://resources.archisketch.com/enterprises/...
# 0   https://resources.archisketch.com/enterprises/...
# 0   https://resources.archisketch.com/enterprises/...
# 0   https://resources.archisketch.com/enterprises/...
# 0   https://resources.archisketch.com/enterprises/...
#
#                    parentId                 createdAt  \
# 0          D0618DD3D2AD4ACF  2020-01-28T05:00:37.293Z
# 1          D0618DD3D2AD4ACF  2020-01-28T05:01:46.053Z
# 2          D0618DD3D2AD4ACF  2020-01-28T05:07:15.234Z
# 3          D0618DD3D2AD4ACF  2020-01-28T05:11:12.445Z
# 0          D0618DD3D2AD4ACF  2020-01-28T05:11:59.987Z
# ..                      ...                       ...
# 0   XrLszCv9134EC572B724DF2  2021-08-20T09:26:26.598Z
# 0   XrLszCv9134EC572B724DF2  2021-08-20T09:26:34.736Z
# 0   XrLszCv9134EC572B724DF2  2021-08-20T09:26:39.236Z
# 0   XrLszCv9134EC572B724DF2  2021-08-20T09:26:44.033Z
# 0   XrLszCv9134EC572B724DF2  2021-08-20T09:26:47.822Z
#
#                    updatedAt
# 0   2020-02-04T08:21:41.079Z
# 1   2020-02-04T08:22:01.978Z
# 2   2020-02-04T08:22:25.474Z
# 3   2021-06-25T02:37:33.522Z
# 0   2020-02-04T08:23:15.345Z
# ..                       ...
# 0   2021-09-06T06:54:58.739Z
# 0   2021-09-06T06:55:22.896Z
# 0   2021-09-06T06:55:35.101Z
# 0   2021-09-06T06:55:50.271Z
# 0   2021-09-06T06:56:51.375Z
#
# [209 rows x 7 columns]

# %%
x.products_json['category_name'] = x.products_json['categories'].apply(lambda x: pd.Series(x)).reset_index(drop=True).drop(columns=1)
# categories_name.apply(find_category)
# Out:
# C:\Users\jumpx\AppData\Local\Temp\ipykernel_16028\3032647042.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   x.products_json['category_name'] = x.products_json['categories'].apply(lambda x: pd.Series(x)).reset_index(drop=True).drop(columns=1)

# %%
prod_a = pd.merge(x.products_json[['_id', 'name', 'category_name']], 
         df[['name', '_id', 'enterpriseId']], 
         left_on='category_name', right_on='_id', how='left')

prod_b = pd.merge(x.products_json[['_id', 'name', 'category_name']], 
         df2[['name', '_id', 'enterpriseId']], 
         left_on='category_name', right_on='_id', how='left').sort_values(by='_id_x')

# %%
prod_a.head()
# Out:
#                      _id_x               name_x            category_name  \
# 0  X5rPclT9CFB7E73DEA8495A                4F_TV  X5sOfKR8EE6E3FB89134354
# 1  Xo7kQN3DC7A5B7C9FE746D6  스마트 라인 LED (화이트)_on  Xo20nqI91CAA7647AA149EF
# 2  XtxfYC1EF0F9090248B4518     브로 사계절 인테리어 러그 S         10D4B42437844E42
# 3  XSWNaDQ8D34AB5317CA4971             맥북프로 13형         1348D5C358224276
# 4  XT21RHb69DF906D42DF4284  원터치 와이드 화이트 휴지통 10L  XrNAUjE123731FDC5D847C0
#
#                   name_y                    _id_y      enterpriseId
# 0                    NaN                      NaN               NaN
# 1  LED Ceiling Lightings  Xo20nqI91CAA7647AA149EF  421B6D0E746C4E6D
# 2                   Rugs         10D4B42437844E42  421B6D0E746C4E6D
# 3                    NaN                      NaN               NaN
# 4                     생활  XrNAUjE123731FDC5D847C0  B57D4F97C0E44A11

# %%
prod_b.head()
# Out:
#                  _id_x                                 name_x  \
# 490   002E454FDD8D4D01  호텔식 더뷰 암막커튼 9colors (창문형/긴창형) (마블그레이)
# 20    0033BB725EF54736                    투명 식물 액자 - 야자 A3사이즈
# 138   009215254E844EE9                          밤부 티슈 케이스 106
# 6663  00E53B958EA24EBF           위더스 컴퓨터책상 1260 2colors (티/화)
# 239   00F723402D634E1F                       선데이 러그 특대형 (그레이)
#
#                 category_name  name_y                    _id_y  \
# 490   XrMYTHY9CB40FCFDDC14991     NaN                      NaN
# 20    XuaCpKo3531C7175AC44FF3  벽/천장장식  XuaCpKo3531C7175AC44FF3
# 138   XuaCriaC3DD13E894674BEF  인테리어소품  XuaCriaC3DD13E894674BEF
# 6663  XrM7nN5EA9A10A8E476454A     NaN                      NaN
# 239   XrMYNApF08F061085254CB7     NaN                      NaN
#
#           enterpriseId
# 490                NaN
# 20    B57D4F97C0E44A11
# 138   B57D4F97C0E44A11
# 6663               NaN
# 239                NaN

# %%
category = pd.concat([prod_a.rename(columns={'name_y':'category_a'}), 
           prod_b[['name_y']].rename(columns={'name_y':'category_b'})], axis=1)

# %%
category
# Out:
#                         _id_x                                        name_x  \
# 0     X5rPclT9CFB7E73DEA8495A                                         4F_TV
# 1     Xo7kQN3DC7A5B7C9FE746D6                           스마트 라인 LED (화이트)_on
# 2     XtxfYC1EF0F9090248B4518                              브로 사계절 인테리어 러그 S
# 3     XSWNaDQ8D34AB5317CA4971                                      맥북프로 13형
# 4     XT21RHb69DF906D42DF4284                           원터치 와이드 화이트 휴지통 10L
# ...                       ...                                           ...
# 9510  XdGlxwz9246FC25CD404DE4                     비올렛 디자인체어 2colors (월넛브라운)
# 9511  XvJtJWPA51ACB9F262E4019                               모뜨 3단 서랍장 (화이트)
# 9512  XhJp_eJBCFF598127BE4AD8  사무용/컴퓨터 메쉬의자 801 화이트프레임 HEAD(포켓스프링 방석) (그레이)
# 9513  Xz-wAFDFF8B0AABAE3B444D           프리미엄 블루투스 홈오디오 모델 XL Model XL (화이트)
# 9514  XxzI_Y6ABD33F648B514ADC     번드 모어 리놀륨 리빙다이닝 4인 코너형 테이블소파 SET L형 (머쉬룸)
#
#                 category_name             category_a                    _id_y  \
# 0     X5sOfKR8EE6E3FB89134354                    NaN                      NaN
# 1     Xo20nqI91CAA7647AA149EF  LED Ceiling Lightings  Xo20nqI91CAA7647AA149EF
# 2            10D4B42437844E42                   Rugs         10D4B42437844E42
# 3            1348D5C358224276                    NaN                      NaN
# 4     XrNAUjE123731FDC5D847C0                     생활  XrNAUjE123731FDC5D847C0
# ...                       ...                    ...                      ...
# 9510  XrLsP5FB1A8CBA8FF744780                     식탁  XrLsP5FB1A8CBA8FF744780
# 9511  XrLs2vMD1BC5D9B32664A60                   일반의자  XrLs2vMD1BC5D9B32664A60
# 9512  XrLrsOTDB80B92F9B9D440E                    서랍장  XrLrsOTDB80B92F9B9D440E
# 9513  XrLs4Lm51A52E3EE5094BE3               학생/오피스의자  XrLs4Lm51A52E3EE5094BE3
# 9514  Xt16pQ0FD730DDB60B042BF                    NaN                      NaN
#
#           enterpriseId           category_b
# 0                  NaN                  NaN
# 1     421B6D0E746C4E6D                  NaN
# 2     421B6D0E746C4E6D                  NaN
# 3                  NaN  Laptops & Portables
# 4     B57D4F97C0E44A11                  NaN
# ...                ...                  ...
# 9510  B57D4F97C0E44A11                  NaN
# 9511  B57D4F97C0E44A11                  NaN
# 9512  B57D4F97C0E44A11                  NaN
# 9513  B57D4F97C0E44A11                  NaN
# 9514               NaN              스피커/라디오
#
# [9515 rows x 7 columns]

# %%
category.head()
# Out:
#                      _id_x               name_x            category_name  \
# 0  X5rPclT9CFB7E73DEA8495A                4F_TV  X5sOfKR8EE6E3FB89134354
# 1  Xo7kQN3DC7A5B7C9FE746D6  스마트 라인 LED (화이트)_on  Xo20nqI91CAA7647AA149EF
# 2  XtxfYC1EF0F9090248B4518     브로 사계절 인테리어 러그 S         10D4B42437844E42
# 3  XSWNaDQ8D34AB5317CA4971             맥북프로 13형         1348D5C358224276
# 4  XT21RHb69DF906D42DF4284  원터치 와이드 화이트 휴지통 10L  XrNAUjE123731FDC5D847C0
#
#               category_a                    _id_y      enterpriseId  \
# 0                    NaN                      NaN               NaN
# 1  LED Ceiling Lightings  Xo20nqI91CAA7647AA149EF  421B6D0E746C4E6D
# 2                   Rugs         10D4B42437844E42  421B6D0E746C4E6D
# 3                    NaN                      NaN               NaN
# 4                     생활  XrNAUjE123731FDC5D847C0  B57D4F97C0E44A11
#
#             category_b
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3  Laptops & Portables
# 4                  NaN

# %%
prod = x.products_json

# %%
prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9515 entries, 0 to 9513
# Data columns (total 40 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               9515 non-null   object
#  1   name              9515 non-null   object
#  2   modelUrl          605 non-null    object
#  3   enterpriseId      9515 non-null   object
#  4   userId            5886 non-null   object
#  5   categories        9515 non-null   object
#  6   archiCategories   4825 non-null   object
#  7   description       4129 non-null   object
#  8   tags              9515 non-null   object
#  9   brand             9206 non-null   object
#  10  sku               7827 non-null   object
#  11  alias             7906 non-null   object
#  12  legacyName        343 non-null    object
#  13  type              9515 non-null   object
#  14  productType       9426 non-null   object
#  15  dimensions        9515 non-null   object
#  16  website           8446 non-null   object
#  17  previewImage      9515 non-null   object
#  18  images            9515 non-null   object
#  19  material          3872 non-null   object
#  20  price             5517 non-null   object
#  21  priceInfo         5435 non-null   object
#  22  rendered          9515 non-null   object
#  23  editorType        9515 non-null   object
#  24  editorAsset       9515 non-null   object
#  25  showInEditor      9515 non-null   object
#  26  lockDimensions    9515 non-null   object
#  27  materialCategory  0 non-null      object
#  28  mappingDimension  0 non-null      object
#  29  renderValues      0 non-null      object
#  30  color             1576 non-null   object
#  31  renderSettings    9118 non-null   object
#  32  renderMaterial    6427 non-null   object
#  33  hdViewerImages    9515 non-null   object
#  34  ar                1570 non-null   object
#  35  option            0 non-null      object
#  36  parentProduct     8328 non-null   object
#  37  createdAt         9515 non-null   object
#  38  updatedAt         9515 non-null   object
#  39  category_name     9485 non-null   object
# dtypes: object(40)
# memory usage: 3.0+ MB

# %%
_id, name, enterprisedId, tags, dimensions, images

# %%
x = pd.merge(prod[['_id', 'name', 'enterpriseId', 'tags', 'dimensions', 'images']], category[['_id_x', 'name_x', 'category_a', 'enterpriseId', 'category_b']], left_on ='_id', right_on = '_id_x')
# Out:
#                           _id                                          name  \
# 0     X5rPclT9CFB7E73DEA8495A                                         4F_TV
# 1     Xo7kQN3DC7A5B7C9FE746D6                           스마트 라인 LED (화이트)_on
# 2     XtxfYC1EF0F9090248B4518                              브로 사계절 인테리어 러그 S
# 3     XSWNaDQ8D34AB5317CA4971                                      맥북프로 13형
# 4     XT21RHb69DF906D42DF4284                           원터치 와이드 화이트 휴지통 10L
# ...                       ...                                           ...
# 9510  XdGlxwz9246FC25CD404DE4                     비올렛 디자인체어 2colors (월넛브라운)
# 9511  XvJtJWPA51ACB9F262E4019                               모뜨 3단 서랍장 (화이트)
# 9512  XhJp_eJBCFF598127BE4AD8  사무용/컴퓨터 메쉬의자 801 화이트프레임 HEAD(포켓스프링 방석) (그레이)
# 9513  Xz-wAFDFF8B0AABAE3B444D           프리미엄 블루투스 홈오디오 모델 XL Model XL (화이트)
# 9514  XxzI_Y6ABD33F648B514ADC     번드 모어 리놀륨 리빙다이닝 4인 코너형 테이블소파 SET L형 (머쉬룸)
#
#         enterpriseId_x                                               tags  \
# 0     15BEED4FED5A48FD                                                 []
# 1     421B6D0E746C4E6D                     [헤이홈, hejhome, 조명, 라인등, 라인LED]
# 2     421B6D0E746C4E6D                      [데이드리머, daydreamer, 러그, 사각러그]
# 3     421B6D0E746C4E6D              [애플, Apple, 맥북, 노트북, 사무용, 사뭉제품, 가전제품]
# 4     B57D4F97C0E44A11  [생활, 생활용품, 휴지통/분리수거함, 휴지통, 분리수거, 분리수거함, 쓰레기통, ...
# ...                ...                                                ...
# 9510  B57D4F97C0E44A11  [일반의자, 식탁의자, 인테리어의자, 주방의자, 블랙, 검정, 검은, 검은색, 인조...
# 9511  B57D4F97C0E44A11                                              [리바트]
# 9512  B57D4F97C0E44A11  [학생의자, 책상의자, 컴퓨터의자, 오피스의자, 화이트, 흰색, 입식, 의자왕, 사...
# 9513  B57D4F97C0E44A11                                           [제네바사운드]
# 9514  B57D4F97C0E44A11                                             [까사미아]
#
#                                              dimensions  \
# 0     {'width': 4200, 'height': 2800, 'depth': 40, '...
# 1     {'width': 2000, 'height': 10, 'depth': 5, 'uni...
# 2     {'width': 2000, 'height': 10, 'depth': 1400, '...
# 3     {'width': 310, 'height': 220, 'depth': 230, 'u...
# 4     {'width': 345, 'height': 299, 'depth': 160, 'u...
# ...                                                 ...
# 9510  {'width': 514, 'height': 780, 'depth': 478, 'u...
# 9511  {'width': 792, 'height': 745, 'depth': 500, 'u...
# 9512  {'width': 590, 'height': 1080, 'depth': 570, '...
# 9513  {'width': 550, 'height': 613, 'depth': 370, 'u...
# 9514  {'width': 2050, 'height': 770, 'depth': 1450, ...
#
#                                                  images  \
# 0     [https://resources.archisketch.com/product/X5r...
# 1     [https://resources.archisketch.com/product/Xo7...
# 2     [https://resources.archisketch.com/product/Xtx...
# 3     [https://resources.archisketch.com/product/XSW...
# 4     [https://resources.archisketch.com/product/XT2...
# ...                                                 ...
# 9510  [https://resources.archisketch.com/product/XdG...
# 9511  [https://resources.archisketch.com/product/XvJ...
# 9512  [https://resources.archisketch.com/product/XhJ...
# 9513  [https://resources.archisketch.com/product/Xz-...
# 9514  [https://resources.archisketch.com/product/Xxz...
#
#                         _id_x                                        name_x  \
# 0     X5rPclT9CFB7E73DEA8495A                                         4F_TV
# 1     Xo7kQN3DC7A5B7C9FE746D6                           스마트 라인 LED (화이트)_on
# 2     XtxfYC1EF0F9090248B4518                              브로 사계절 인테리어 러그 S
# 3     XSWNaDQ8D34AB5317CA4971                                      맥북프로 13형
# 4     XT21RHb69DF906D42DF4284                           원터치 와이드 화이트 휴지통 10L
# ...                       ...                                           ...
# 9510  XdGlxwz9246FC25CD404DE4                     비올렛 디자인체어 2colors (월넛브라운)
# 9511  XvJtJWPA51ACB9F262E4019                               모뜨 3단 서랍장 (화이트)
# 9512  XhJp_eJBCFF598127BE4AD8  사무용/컴퓨터 메쉬의자 801 화이트프레임 HEAD(포켓스프링 방석) (그레이)
# 9513  Xz-wAFDFF8B0AABAE3B444D           프리미엄 블루투스 홈오디오 모델 XL Model XL (화이트)
# 9514  XxzI_Y6ABD33F648B514ADC     번드 모어 리놀륨 리빙다이닝 4인 코너형 테이블소파 SET L형 (머쉬룸)
#
#                  category_a    enterpriseId_y           category_b
# 0                       NaN               NaN                  NaN
# 1     LED Ceiling Lightings  421B6D0E746C4E6D                  NaN
# 2                      Rugs  421B6D0E746C4E6D                  NaN
# 3                       NaN               NaN  Laptops & Portables
# 4                        생활  B57D4F97C0E44A11                  NaN
# ...                     ...               ...                  ...
# 9510                     식탁  B57D4F97C0E44A11                  NaN
# 9511                   일반의자  B57D4F97C0E44A11                  NaN
# 9512                    서랍장  B57D4F97C0E44A11                  NaN
# 9513               학생/오피스의자  B57D4F97C0E44A11                  NaN
# 9514                    NaN               NaN              스피커/라디오
#
# [9515 rows x 11 columns]

# %%
x
# Out:
#                           _id                                          name  \
# 0     X5rPclT9CFB7E73DEA8495A                                         4F_TV
# 1     Xo7kQN3DC7A5B7C9FE746D6                           스마트 라인 LED (화이트)_on
# 2     XtxfYC1EF0F9090248B4518                              브로 사계절 인테리어 러그 S
# 3     XSWNaDQ8D34AB5317CA4971                                      맥북프로 13형
# 4     XT21RHb69DF906D42DF4284                           원터치 와이드 화이트 휴지통 10L
# ...                       ...                                           ...
# 9510  XdGlxwz9246FC25CD404DE4                     비올렛 디자인체어 2colors (월넛브라운)
# 9511  XvJtJWPA51ACB9F262E4019                               모뜨 3단 서랍장 (화이트)
# 9512  XhJp_eJBCFF598127BE4AD8  사무용/컴퓨터 메쉬의자 801 화이트프레임 HEAD(포켓스프링 방석) (그레이)
# 9513  Xz-wAFDFF8B0AABAE3B444D           프리미엄 블루투스 홈오디오 모델 XL Model XL (화이트)
# 9514  XxzI_Y6ABD33F648B514ADC     번드 모어 리놀륨 리빙다이닝 4인 코너형 테이블소파 SET L형 (머쉬룸)
#
#         enterpriseId_x                                               tags  \
# 0     15BEED4FED5A48FD                                                 []
# 1     421B6D0E746C4E6D                     [헤이홈, hejhome, 조명, 라인등, 라인LED]
# 2     421B6D0E746C4E6D                      [데이드리머, daydreamer, 러그, 사각러그]
# 3     421B6D0E746C4E6D              [애플, Apple, 맥북, 노트북, 사무용, 사뭉제품, 가전제품]
# 4     B57D4F97C0E44A11  [생활, 생활용품, 휴지통/분리수거함, 휴지통, 분리수거, 분리수거함, 쓰레기통, ...
# ...                ...                                                ...
# 9510  B57D4F97C0E44A11  [일반의자, 식탁의자, 인테리어의자, 주방의자, 블랙, 검정, 검은, 검은색, 인조...
# 9511  B57D4F97C0E44A11                                              [리바트]
# 9512  B57D4F97C0E44A11  [학생의자, 책상의자, 컴퓨터의자, 오피스의자, 화이트, 흰색, 입식, 의자왕, 사...
# 9513  B57D4F97C0E44A11                                           [제네바사운드]
# 9514  B57D4F97C0E44A11                                             [까사미아]
#
#                                              dimensions  \
# 0     {'width': 4200, 'height': 2800, 'depth': 40, '...
# 1     {'width': 2000, 'height': 10, 'depth': 5, 'uni...
# 2     {'width': 2000, 'height': 10, 'depth': 1400, '...
# 3     {'width': 310, 'height': 220, 'depth': 230, 'u...
# 4     {'width': 345, 'height': 299, 'depth': 160, 'u...
# ...                                                 ...
# 9510  {'width': 514, 'height': 780, 'depth': 478, 'u...
# 9511  {'width': 792, 'height': 745, 'depth': 500, 'u...
# 9512  {'width': 590, 'height': 1080, 'depth': 570, '...
# 9513  {'width': 550, 'height': 613, 'depth': 370, 'u...
# 9514  {'width': 2050, 'height': 770, 'depth': 1450, ...
#
#                                                  images  \
# 0     [https://resources.archisketch.com/product/X5r...
# 1     [https://resources.archisketch.com/product/Xo7...
# 2     [https://resources.archisketch.com/product/Xtx...
# 3     [https://resources.archisketch.com/product/XSW...
# 4     [https://resources.archisketch.com/product/XT2...
# ...                                                 ...
# 9510  [https://resources.archisketch.com/product/XdG...
# 9511  [https://resources.archisketch.com/product/XvJ...
# 9512  [https://resources.archisketch.com/product/XhJ...
# 9513  [https://resources.archisketch.com/product/Xz-...
# 9514  [https://resources.archisketch.com/product/Xxz...
#
#                         _id_x                                        name_x  \
# 0     X5rPclT9CFB7E73DEA8495A                                         4F_TV
# 1     Xo7kQN3DC7A5B7C9FE746D6                           스마트 라인 LED (화이트)_on
# 2     XtxfYC1EF0F9090248B4518                              브로 사계절 인테리어 러그 S
# 3     XSWNaDQ8D34AB5317CA4971                                      맥북프로 13형
# 4     XT21RHb69DF906D42DF4284                           원터치 와이드 화이트 휴지통 10L
# ...                       ...                                           ...
# 9510  XdGlxwz9246FC25CD404DE4                     비올렛 디자인체어 2colors (월넛브라운)
# 9511  XvJtJWPA51ACB9F262E4019                               모뜨 3단 서랍장 (화이트)
# 9512  XhJp_eJBCFF598127BE4AD8  사무용/컴퓨터 메쉬의자 801 화이트프레임 HEAD(포켓스프링 방석) (그레이)
# 9513  Xz-wAFDFF8B0AABAE3B444D           프리미엄 블루투스 홈오디오 모델 XL Model XL (화이트)
# 9514  XxzI_Y6ABD33F648B514ADC     번드 모어 리놀륨 리빙다이닝 4인 코너형 테이블소파 SET L형 (머쉬룸)
#
#                  category_a    enterpriseId_y           category_b
# 0                       NaN               NaN                  NaN
# 1     LED Ceiling Lightings  421B6D0E746C4E6D                  NaN
# 2                      Rugs  421B6D0E746C4E6D                  NaN
# 3                       NaN               NaN  Laptops & Portables
# 4                        생활  B57D4F97C0E44A11                  NaN
# ...                     ...               ...                  ...
# 9510                     식탁  B57D4F97C0E44A11                  NaN
# 9511                   일반의자  B57D4F97C0E44A11                  NaN
# 9512                    서랍장  B57D4F97C0E44A11                  NaN
# 9513               학생/오피스의자  B57D4F97C0E44A11                  NaN
# 9514                    NaN               NaN              스피커/라디오
#
# [9515 rows x 11 columns]

# %%
x.products_4.head(10)
# Out:
#       enterprise_id             top_style_1 top_style  \
# 0  421B6D0E746C4E6D       [MODERN, NATURAL]    MODERN
# 1  421B6D0E746C4E6D                [MODERN]    MODERN
# 2  421B6D0E746C4E6D  [MODERN, SCANDINAVIAN]    MODERN
# 3  421B6D0E746C4E6D                [MODERN]    MODERN
# 4  421B6D0E746C4E6D                [MODERN]    MODERN
# 5  421B6D0E746C4E6D                [MODERN]    MODERN
# 6  421B6D0E746C4E6D                [MODERN]    MODERN
# 7  421B6D0E746C4E6D       [MODERN, NATURAL]    MODERN
# 8  421B6D0E746C4E6D               [NATURAL]   NATURAL
# 9  421B6D0E746C4E6D               [NATURAL]   NATURAL
#
#                  projectId  awesome_score               product_id  \
# 0  X9IceC_16DC38C091A6439F       0.984499         6E3531E25BF343BE
# 1  X5WaEry9CEC543A4961492E       0.987451  XYW9sOc9CC9CD1261C74F5E
# 2  X3cjAHq297A348CEE5B4698       0.904893         9685F6318BD040E1
# 3  X8HTtd3A494EC74B8EA45A3       0.956234         9685F6318BD040E1
# 4  X4kGJoQA6F0C0CB39874510       0.902196         9685F6318BD040E1
# 5  X4kGJoQA6F0C0CB39874510       0.877599         9685F6318BD040E1
# 6  X4LFItPB5B85DFF6CFE4EFE       0.963457         9685F6318BD040E1
# 7  X9IceC_16DC38C091A6439F       0.984499         2F173085E1BC4D5A
# 8  X8GARgr482B5458C0D64C80       0.966516         2F173085E1BC4D5A
# 9  XXQC1c784250E851FC64BF5       0.874387         2F173085E1BC4D5A
#
#                                                 tags                   name  \
# 0                                                 []  투명 식물 액자 - 몬스테라 A3사이즈
# 1  [조명, 무드등/장식조명, 무드등, 무드, 브라운, 갈색, 무드등/수면등, 무드등,...       우리집 속 불멍 벽난로 무드등
# 2                            [커튼, 데코뷰, 호텔식, 화이트, 시폰]          호텔식 화이트 시폰 커튼
# 3                            [커튼, 데코뷰, 호텔식, 화이트, 시폰]          호텔식 화이트 시폰 커튼
# 4                            [커튼, 데코뷰, 호텔식, 화이트, 시폰]          호텔식 화이트 시폰 커튼
# 5                            [커튼, 데코뷰, 호텔식, 화이트, 시폰]          호텔식 화이트 시폰 커튼
# 6                            [커튼, 데코뷰, 호텔식, 화이트, 시폰]          호텔식 화이트 시폰 커튼
# 7  [플라워/식물, 플라워, 식물, 플랜트, 플랜테리어, 플렌트, 식물데코, 식물인테리...   코코넛 마크라메 행잉플랜트 (아이비)
# 8  [플라워/식물, 플라워, 식물, 플랜트, 플랜테리어, 플렌트, 식물데코, 식물인테리...   코코넛 마크라메 행잉플랜트 (아이비)
# 9  [플라워/식물, 플라워, 식물, 플랜트, 플랜테리어, 플렌트, 식물데코, 식물인테리...   코코넛 마크라메 행잉플랜트 (아이비)
#
#                                               images  \
# 0  [https://resources.archisketch.com/product/6E3...
# 1  [https://resources.archisketch.com/product/XYW...
# 2  [https://resources.archisketch.com/product/968...
# 3  [https://resources.archisketch.com/product/968...
# 4  [https://resources.archisketch.com/product/968...
# 5  [https://resources.archisketch.com/product/968...
# 6  [https://resources.archisketch.com/product/968...
# 7  [https://resources.archisketch.com/product/2F1...
# 8  [https://resources.archisketch.com/product/2F1...
# 9  [https://resources.archisketch.com/product/2F1...
#
#                   categories  use_count            category_name  \
# 0  [XuaCpKo3531C7175AC44FF3]         33  XuaCpKo3531C7175AC44FF3
# 1  [XrM7nN5EA9A10A8E476454A]         31  XrM7nN5EA9A10A8E476454A
# 2  [XrMYTHY9CB40FCFDDC14991]        460  XrMYTHY9CB40FCFDDC14991
# 3  [XrMYTHY9CB40FCFDDC14991]        460  XrMYTHY9CB40FCFDDC14991
# 4  [XrMYTHY9CB40FCFDDC14991]        460  XrMYTHY9CB40FCFDDC14991
# 5  [XrMYTHY9CB40FCFDDC14991]        460  XrMYTHY9CB40FCFDDC14991
# 6  [XrMYTHY9CB40FCFDDC14991]        460  XrMYTHY9CB40FCFDDC14991
# 7  [XuaE2XS5FD2BDA113084B15]         85  XuaE2XS5FD2BDA113084B15
# 8  [XuaE2XS5FD2BDA113084B15]         85  XuaE2XS5FD2BDA113084B15
# 9  [XuaE2XS5FD2BDA113084B15]         85  XuaE2XS5FD2BDA113084B15
#
#                        _id name_x    name_y
# 0                      NaN    NaN       NaN
# 1  XrM7nN5EA9A10A8E476454A     조명  무드등/장식조명
# 2  XrMYTHY9CB40FCFDDC14991    패브릭        커튼
# 3  XrMYTHY9CB40FCFDDC14991    패브릭        커튼
# 4  XrMYTHY9CB40FCFDDC14991    패브릭        커튼
# 5  XrMYTHY9CB40FCFDDC14991    패브릭        커튼
# 6  XrMYTHY9CB40FCFDDC14991    패브릭        커튼
# 7                      NaN    NaN       NaN
# 8                      NaN    NaN       NaN
# 9                      NaN    NaN       NaN

# %%
import pandas as pd
import json

class Preprocess:
    
    def __init__(self, best, item, products, category, style_ths=0.1):
        """
        style_ths : top_style_predictions 에서 범위 조절 (e.g. 0.1 이상으로 예측 점수를 받은 스타일만 받아옴 - maximum 3개)
        """
        self.style_ths = style_ths
        self.style_ths_name = str(style_ths)[-1]
        
        self.best = best
        self.item = item
        self.products = products
        self.category = category
        
        self.best_json = self.read_json(best)
        self.item_json = self.read_json(item)
        self.products_json = self.read_json(products).drop_duplicates('_id') # products json duplicated deleted
        self.category_json = self.read_json2(category).reset_index(drop=True)
        self.best_item, self.category,self.products_4, self.products_b = self.preprocess(self.best_json, 
                                                                           self.item_json, 
                                                                           self.products_json, 
                                                                           self.category_json)

    def read_json(self,json_file):
        df = pd.DataFrame()
        if json_file != self.products:  
            for file in json_file:
                x = pd.read_json(file)
                df = pd.concat([df, x])
        else:
            # why -> products json duplicated 
            for file in json_file:
                x = pd.read_json(file).T.reset_index(drop=True)    
                df = pd.concat([df, x])
        return df

    def read_json2(self,category):
        for i in category:
            with open(i) as js:
                json_data = json.load(js)
        cat_4, cat_b = pd.DataFrame(json_data['421B6D0E746C4E6D']), pd.DataFrame(json_data['B57D4F97C0E44A11'])
        category = pd.concat([cat_4, cat_b])
        return category
    
    def get_productId(self, items_list):
        new_list = []
        for item in items_list:
            new_list.append(item['productId'])
        return new_list
    
    # category['children'] -> name(label) 
    def find_category_df(self, category):
        df = pd.DataFrame()
        for i in category['children']:
            df2 = pd.DataFrame(i)
            df = pd.concat([df, df2])
        return df
        
    def preprocess(self, best, item, products, category):
        
        item.rename(columns={'enterpriseId':'enterprise_id', '_id':'id'}, inplace=True)
        templates = pd.merge(best, item, on=['enterprise_id', 'projectId', 'id'])
        
        # 2 enterprise id 
        ent2, ent1 = templates['enterprise_id'].unique().tolist()
        
        # get item_id 
        templates['items'] = templates['items'].apply(self.get_productId)
        
        # find_category_id_preprocess
    
        # edit new columns style_name, style_score > 0.1 
        templates[f'top_style_{self.style_ths_name}'] = templates['style_predictions'].apply(lambda x: sorted([(name, score) for name, score in x.items() if score > self.style_ths], key=lambda x: x[1], reverse=True)[:3])
        # del list, style score
        templates[f'top_style_{self.style_ths_name}'] = templates[f'top_style_{self.style_ths_name}'].apply(lambda x: [name for name, score in x])
        # Edit best_item['items'] = list(values) -> values
        items_stack = pd.DataFrame(templates['items'].apply(lambda x: pd.Series(x)).stack()).reset_index(1, drop=True) 
        products_df = pd.merge(templates[['enterprise_id', 
                                          f'top_style_{self.style_ths_name}', 
                                          'top_style', 
                                          'projectId', 
                                          'awesome_score']].reset_index(), 
                               items_stack.reset_index(), 
                               on='index').drop(['index'], axis=1).rename(columns = {0:'product_id'})
        prod_tags_df = products[['_id', 'tags', 'name', 'images', 'categories']]
        products_df = pd.merge(products_df, 
                               prod_tags_df, 
                               left_on='product_id', 
                               right_on='_id').drop(['_id'], axis=1)
        products_df = pd.merge(products_df, 
                               products_df['product_id'].value_counts().reset_index(),
                               left_on='product_id',
                               right_on='index').rename(columns = {'product_id_x': 'product_id',
                                                                   'product_id_y':'use_count'}).drop(['index'], axis=1)
        
        # category[categories] = list(values) -> values
        products_df['category_name'] = products_df['categories'].apply(lambda x: pd.Series(x)).reset_index(drop=True).drop(columns=1)
        
        
        ## new code
        # find_category_id_preprocess
        cat_a = find_category_df(DATA.category_json)
        cat_a = pd.merge(cat_df[['_id', 'name']], 
                         cat_a[['name', '_id', 'enterpriseId', 'parentId', 'children']], 
                         left_on='_id', right_on='parentId').drop(['parentId'], axis=1)
        
        cat_b = find_category_df(cat_a)
        cat_b = pd.merge(cat_df[['_id', 'name']], 
                 cat_b[['name', 'enterpriseId', 'parentId', 'grandparentId', '_id']], 
                 left_on='_id', 
                 right_on='grandparentId').drop(['grandparentId'], axis=1)
        
        self.products_json['category_name'] = self.products_json['categories'].apply(lambda x: pd.Series(x)).reset_index(drop=True).drop(columns=1)
        
        # category_df['name_x'] = category['children']
        # category_df['name_y'] = category['children'][children]
        prod_a = pd.merge(self.products_json[['_id', 'name', 'category_name']], 
                         cat_a[['name_x', 'name_y', '_id_y', 'enterpriseId', 'children']], 
                         left_on='category_name', right_on='_id_y', how='left').drop(['_id_y'], axis=1)
        
        prod_b = pd.merge(self.products_json[['_id', 'name', 'category_name']], 
                         cat_b[['name_x', 'name_y', '_id_y', 'enterpriseId']], 
                         left_on='category_name', right_on='_id_y', how='left').drop(['_id_y'], axis=1)
        
        category_df = pd.merge(prod_a, 
                         prod_b[['_id', 'category_name', 'name_x', 'name_y']].rename(columns={'name_y':'name_z'}),
                         on='_id'
                        )
        
        category_df.columns = ['product_id', 'name', 
                            'name_x', 'name_y', 
                            'enterpriseId', 'name_z']
        category_df = category_df[['product_id', 'name', 
                                'name_x', 'name_y', 'name_z', 
                                'enterpriseId']]
        
        category_df = pd.merge(self.products_json[['_id', 'name', 'tags', 'dimensions', 'images']], 
                               category_df[['product_id', 'name_x', 'name_y', 'name_z']], 
                               on = 'product_id')
        
        products_df = pd.merge(products_df[['enterprise_id', 'projectId', 'top_style_1', 
                                            'top_style', 'awesome_score', 'product_id', 'use_count']], 
                               category_df, 
                               on='product_id')
        
        products_df_4 = products_df[products_df['enterprise_id'] == ent1].reset_index(drop=True)
        products_df_b = products_df[products_df['enterprise_id'] == ent2].reset_index(drop=True)
        
        return templates,category_df, products_df_4, products_df_b
